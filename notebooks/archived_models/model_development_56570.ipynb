# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, MaxPooling2D, BatchNormalization, Conv2D, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# 2023-12-20 14:14:42.312688: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-20 14:14:42.938650: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Image Specifications
folder_path = "../dataset/MMAFEDB/"
image_dimension = (48, 48)
image_depth = 3
image_color_mode = 'rgb'
batch_size = 512

# Data Augmentation for Training Set
datagen_train = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Only rescaling for Validation Set
datagen_val = ImageDataGenerator(rescale=1./255)

train_set = datagen_train.flow_from_directory(
    folder_path + "train",
    target_size=image_dimension,
    color_mode=image_color_mode,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

test_set = datagen_val.flow_from_directory(
    folder_path + "valid",
    target_size=image_dimension,
    color_mode=image_color_mode,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Get the total number of images in the training set
total_images_train = train_set.n
print("Total images in training set:", total_images_train)
# Get the total number of images in the training set
total_images_test = test_set.n
print("Total images in test set:", total_images_test)
# Out:
# Found 92968 images belonging to 7 classes.
# Found 17356 images belonging to 7 classes.
# Total images in training set: 92968
# Total images in test set: 17356

# %%
drop_rate = 0.3

# Create sequential model
model = Sequential()

###########
# Model 2
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', 
                         input_shape=(48, 48, 3)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
 
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
###########

initial_learning_rate = 0.0001
lr_schedule = ExponentialDecay(initial_learning_rate, decay_steps=100000, decay_rate=0.96)
optimizer_adam = Adam(learning_rate=lr_schedule)

# Compile model
model.compile(
    optimizer=optimizer_adam,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        18496
#
#  max_pooling2d (MaxPooling2  (None, 22, 22, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 2346183 (8.95 MB)
# Trainable params: 2346183 (8.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-12-20 14:14:45.682739: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 14:14:45.708548: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 14:14:45.708789: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 14:14:45.709817: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 14:14:45.710018: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 14:14:45.710199: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 14:14:46.217485: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 14:14:46.217712: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 14:14:46.217903: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 14:14:46.218065: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3554 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Define hyperparameters
epochs = 100

# Set up model checkpoint
checkpoint = ModelCheckpoint(
    "model_weights2.h5",
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max'
)
callbacks_list = [checkpoint]

# Train the model
history = model.fit(
    train_set,
    validation_data=test_set,
    steps_per_epoch=total_images_train // batch_size,
    validation_steps=total_images_test // batch_size,
    epochs=epochs,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/100
# 2023-12-20 14:14:47.289962: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-12-20 14:14:48.573489: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2023-12-20 14:14:49.575062: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-20 14:14:49.578262: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fb634e31640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-20 14:14:49.578280: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2023-12-20 14:14:49.581691: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-20 14:14:49.674424: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 181/181 [==============================] - ETA: 0s - loss: 1.6402 - accuracy: 0.3397
# Epoch 1: val_accuracy improved from -inf to 0.33339, saving model to model_weights2.h5
# 181/181 [==============================] - 59s 276ms/step - loss: 1.6402 - accuracy: 0.3397 - val_loss: 1.6363 - val_accuracy: 0.3334
# Epoch 2/100
# /home/fox/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 181/181 [==============================] - ETA: 0s - loss: 1.5466 - accuracy: 0.4010
# Epoch 2: val_accuracy improved from 0.33339 to 0.38909, saving model to model_weights2.h5
# 181/181 [==============================] - 48s 266ms/step - loss: 1.5466 - accuracy: 0.4010 - val_loss: 1.5591 - val_accuracy: 0.3891
# Epoch 3/100
# 181/181 [==============================] - ETA: 0s - loss: 1.4620 - accuracy: 0.4530
# Epoch 3: val_accuracy improved from 0.38909 to 0.42004, saving model to model_weights2.h5
# 181/181 [==============================] - 48s 263ms/step - loss: 1.4620 - accuracy: 0.4530 - val_loss: 1.5159 - val_accuracy: 0.4200
# Epoch 4/100
# 181/181 [==============================] - ETA: 0s - loss: 1.3984 - accuracy: 0.4885
# Epoch 4: val_accuracy improved from 0.42004 to 0.44543, saving model to model_weights2.h5
# 181/181 [==============================] - 48s 263ms/step - loss: 1.3984 - accuracy: 0.4885 - val_loss: 1.4932 - val_accuracy: 0.4454
# Epoch 5/100
# 181/181 [==============================] - ETA: 0s - loss: 1.3578 - accuracy: 0.5056
# Epoch 5: val_accuracy improved from 0.44543 to 0.45520, saving model to model_weights2.h5
# 181/181 [==============================] - 48s 263ms/step - loss: 1.3578 - accuracy: 0.5056 - val_loss: 1.4652 - val_accuracy: 0.4552
# Epoch 6/100
# 181/181 [==============================] - ETA: 0s - loss: 1.3264 - accuracy: 0.5186
# Epoch 6: val_accuracy improved from 0.45520 to 0.45745, saving model to model_weights2.h5
# 181/181 [==============================] - 48s 264ms/step - loss: 1.3264 - accuracy: 0.5186 - val_loss: 1.4923 - val_accuracy: 0.4574
# Epoch 7/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2991 - accuracy: 0.5304
# Epoch 7: val_accuracy improved from 0.45745 to 0.46384, saving model to model_weights2.h5
# 181/181 [==============================] - 47s 259ms/step - loss: 1.2991 - accuracy: 0.5304 - val_loss: 1.4564 - val_accuracy: 0.4638
# Epoch 8/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2744 - accuracy: 0.5389
# Epoch 8: val_accuracy improved from 0.46384 to 0.47662, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 255ms/step - loss: 1.2744 - accuracy: 0.5389 - val_loss: 1.4261 - val_accuracy: 0.4766
# Epoch 9/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2519 - accuracy: 0.5503
# Epoch 9: val_accuracy improved from 0.47662 to 0.47727, saving model to model_weights2.h5
# 181/181 [==============================] - 47s 257ms/step - loss: 1.2519 - accuracy: 0.5503 - val_loss: 1.4305 - val_accuracy: 0.4773
# Epoch 10/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2334 - accuracy: 0.5574
# Epoch 10: val_accuracy did not improve from 0.47727
# 181/181 [==============================] - 47s 258ms/step - loss: 1.2334 - accuracy: 0.5574 - val_loss: 1.4385 - val_accuracy: 0.4720
# Epoch 11/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2136 - accuracy: 0.5651
# Epoch 11: val_accuracy improved from 0.47727 to 0.48290, saving model to model_weights2.h5
# 181/181 [==============================] - 47s 260ms/step - loss: 1.2136 - accuracy: 0.5651 - val_loss: 1.4122 - val_accuracy: 0.4829
# Epoch 12/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1956 - accuracy: 0.5714
# Epoch 12: val_accuracy did not improve from 0.48290
# 181/181 [==============================] - 46s 256ms/step - loss: 1.1956 - accuracy: 0.5714 - val_loss: 1.4498 - val_accuracy: 0.4711
# Epoch 13/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1806 - accuracy: 0.5773
# Epoch 13: val_accuracy improved from 0.48290 to 0.48680, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 256ms/step - loss: 1.1806 - accuracy: 0.5773 - val_loss: 1.4173 - val_accuracy: 0.4868
# Epoch 14/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1660 - accuracy: 0.5839
# Epoch 14: val_accuracy improved from 0.48680 to 0.49390, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 256ms/step - loss: 1.1660 - accuracy: 0.5839 - val_loss: 1.3773 - val_accuracy: 0.4939
# Epoch 15/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1550 - accuracy: 0.5877
# Epoch 15: val_accuracy did not improve from 0.49390
# 181/181 [==============================] - 46s 255ms/step - loss: 1.1550 - accuracy: 0.5877 - val_loss: 1.3880 - val_accuracy: 0.4934
# Epoch 16/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1399 - accuracy: 0.5929
# Epoch 16: val_accuracy did not improve from 0.49390
# 181/181 [==============================] - 46s 256ms/step - loss: 1.1399 - accuracy: 0.5929 - val_loss: 1.3934 - val_accuracy: 0.4931
# Epoch 17/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1305 - accuracy: 0.5978
# Epoch 17: val_accuracy improved from 0.49390 to 0.50752, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 256ms/step - loss: 1.1305 - accuracy: 0.5978 - val_loss: 1.3567 - val_accuracy: 0.5075
# Epoch 18/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1194 - accuracy: 0.6015
# Epoch 18: val_accuracy did not improve from 0.50752
# 181/181 [==============================] - 47s 258ms/step - loss: 1.1194 - accuracy: 0.6015 - val_loss: 1.3595 - val_accuracy: 0.5046
# Epoch 19/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1104 - accuracy: 0.6048
# Epoch 19: val_accuracy improved from 0.50752 to 0.51361, saving model to model_weights2.h5
# 181/181 [==============================] - 47s 257ms/step - loss: 1.1104 - accuracy: 0.6048 - val_loss: 1.3340 - val_accuracy: 0.5136
# Epoch 20/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1010 - accuracy: 0.6096
# Epoch 20: val_accuracy did not improve from 0.51361
# 181/181 [==============================] - 46s 254ms/step - loss: 1.1010 - accuracy: 0.6096 - val_loss: 1.3586 - val_accuracy: 0.5080
# Epoch 21/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0939 - accuracy: 0.6099
# Epoch 21: val_accuracy did not improve from 0.51361
# 181/181 [==============================] - 46s 255ms/step - loss: 1.0939 - accuracy: 0.6099 - val_loss: 1.3527 - val_accuracy: 0.5076
# Epoch 22/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0850 - accuracy: 0.6147
# Epoch 22: val_accuracy did not improve from 0.51361
# 181/181 [==============================] - 46s 252ms/step - loss: 1.0850 - accuracy: 0.6147 - val_loss: 1.3627 - val_accuracy: 0.5081
# Epoch 23/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0816 - accuracy: 0.6157
# Epoch 23: val_accuracy did not improve from 0.51361
# 181/181 [==============================] - 46s 256ms/step - loss: 1.0816 - accuracy: 0.6157 - val_loss: 1.3479 - val_accuracy: 0.5111
# Epoch 24/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0742 - accuracy: 0.6196
# Epoch 24: val_accuracy did not improve from 0.51361
# 181/181 [==============================] - 46s 256ms/step - loss: 1.0742 - accuracy: 0.6196 - val_loss: 1.3512 - val_accuracy: 0.5124
# Epoch 25/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0673 - accuracy: 0.6223
# Epoch 25: val_accuracy improved from 0.51361 to 0.51480, saving model to model_weights2.h5
# 181/181 [==============================] - 47s 258ms/step - loss: 1.0673 - accuracy: 0.6223 - val_loss: 1.3485 - val_accuracy: 0.5148
# Epoch 26/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0599 - accuracy: 0.6227
# Epoch 26: val_accuracy improved from 0.51480 to 0.52415, saving model to model_weights2.h5
# 181/181 [==============================] - 47s 257ms/step - loss: 1.0599 - accuracy: 0.6227 - val_loss: 1.3130 - val_accuracy: 0.5241
# Epoch 27/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0525 - accuracy: 0.6267
# Epoch 27: val_accuracy did not improve from 0.52415
# 181/181 [==============================] - 46s 255ms/step - loss: 1.0525 - accuracy: 0.6267 - val_loss: 1.3179 - val_accuracy: 0.5231
# Epoch 28/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0494 - accuracy: 0.6264
# Epoch 28: val_accuracy did not improve from 0.52415
# 181/181 [==============================] - 46s 256ms/step - loss: 1.0494 - accuracy: 0.6264 - val_loss: 1.3477 - val_accuracy: 0.5149
# Epoch 29/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0454 - accuracy: 0.6279
# Epoch 29: val_accuracy improved from 0.52415 to 0.52953, saving model to model_weights2.h5
# 181/181 [==============================] - 47s 257ms/step - loss: 1.0454 - accuracy: 0.6279 - val_loss: 1.3086 - val_accuracy: 0.5295
# Epoch 30/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0376 - accuracy: 0.6315
# Epoch 30: val_accuracy did not improve from 0.52953
# 181/181 [==============================] - 46s 254ms/step - loss: 1.0376 - accuracy: 0.6315 - val_loss: 1.3082 - val_accuracy: 0.5285
# Epoch 31/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0327 - accuracy: 0.6331
# Epoch 31: val_accuracy improved from 0.52953 to 0.53018, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 253ms/step - loss: 1.0327 - accuracy: 0.6331 - val_loss: 1.3059 - val_accuracy: 0.5302
# Epoch 32/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0296 - accuracy: 0.6352
# Epoch 32: val_accuracy improved from 0.53018 to 0.53255, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 256ms/step - loss: 1.0296 - accuracy: 0.6352 - val_loss: 1.2964 - val_accuracy: 0.5326
# Epoch 33/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0207 - accuracy: 0.6363
# Epoch 33: val_accuracy did not improve from 0.53255
# 181/181 [==============================] - 46s 254ms/step - loss: 1.0207 - accuracy: 0.6363 - val_loss: 1.3069 - val_accuracy: 0.5323
# Epoch 34/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0198 - accuracy: 0.6382
# Epoch 34: val_accuracy improved from 0.53255 to 0.53971, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 256ms/step - loss: 1.0198 - accuracy: 0.6382 - val_loss: 1.2820 - val_accuracy: 0.5397
# Epoch 35/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0155 - accuracy: 0.6401
# Epoch 35: val_accuracy did not improve from 0.53971
# 181/181 [==============================] - 48s 262ms/step - loss: 1.0155 - accuracy: 0.6401 - val_loss: 1.3168 - val_accuracy: 0.5265
# Epoch 36/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0125 - accuracy: 0.6408
# Epoch 36: val_accuracy did not improve from 0.53971
# 181/181 [==============================] - 47s 257ms/step - loss: 1.0125 - accuracy: 0.6408 - val_loss: 1.2796 - val_accuracy: 0.5348
# Epoch 37/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0053 - accuracy: 0.6435
# Epoch 37: val_accuracy did not improve from 0.53971
# 181/181 [==============================] - 46s 255ms/step - loss: 1.0053 - accuracy: 0.6435 - val_loss: 1.2850 - val_accuracy: 0.5378
# Epoch 38/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0045 - accuracy: 0.6433
# Epoch 38: val_accuracy did not improve from 0.53971
# 181/181 [==============================] - 47s 258ms/step - loss: 1.0045 - accuracy: 0.6433 - val_loss: 1.3254 - val_accuracy: 0.5282
# Epoch 39/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0004 - accuracy: 0.6442
# Epoch 39: val_accuracy did not improve from 0.53971
# 181/181 [==============================] - 47s 257ms/step - loss: 1.0004 - accuracy: 0.6442 - val_loss: 1.2944 - val_accuracy: 0.5340
# Epoch 40/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9976 - accuracy: 0.6453
# Epoch 40: val_accuracy improved from 0.53971 to 0.54113, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 255ms/step - loss: 0.9976 - accuracy: 0.6453 - val_loss: 1.2720 - val_accuracy: 0.5411
# Epoch 41/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9933 - accuracy: 0.6473
# Epoch 41: val_accuracy did not improve from 0.54113
# 181/181 [==============================] - 46s 255ms/step - loss: 0.9933 - accuracy: 0.6473 - val_loss: 1.2907 - val_accuracy: 0.5409
# Epoch 42/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9905 - accuracy: 0.6479
# Epoch 42: val_accuracy improved from 0.54113 to 0.54332, saving model to model_weights2.h5
# 181/181 [==============================] - 47s 261ms/step - loss: 0.9905 - accuracy: 0.6479 - val_loss: 1.2803 - val_accuracy: 0.5433
# Epoch 43/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9845 - accuracy: 0.6515
# Epoch 43: val_accuracy did not improve from 0.54332
# 181/181 [==============================] - 48s 266ms/step - loss: 0.9845 - accuracy: 0.6515 - val_loss: 1.3282 - val_accuracy: 0.5252
# Epoch 44/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9835 - accuracy: 0.6499
# Epoch 44: val_accuracy did not improve from 0.54332
# 181/181 [==============================] - 48s 263ms/step - loss: 0.9835 - accuracy: 0.6499 - val_loss: 1.3222 - val_accuracy: 0.5279
# Epoch 45/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9813 - accuracy: 0.6533
# Epoch 45: val_accuracy did not improve from 0.54332
# 181/181 [==============================] - 48s 263ms/step - loss: 0.9813 - accuracy: 0.6533 - val_loss: 1.2728 - val_accuracy: 0.5398
# Epoch 46/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9774 - accuracy: 0.6532
# Epoch 46: val_accuracy improved from 0.54332 to 0.54563, saving model to model_weights2.h5
# 181/181 [==============================] - 48s 267ms/step - loss: 0.9774 - accuracy: 0.6532 - val_loss: 1.2686 - val_accuracy: 0.5456
# Epoch 47/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9734 - accuracy: 0.6565
# Epoch 47: val_accuracy improved from 0.54563 to 0.54599, saving model to model_weights2.h5
# 181/181 [==============================] - 48s 264ms/step - loss: 0.9734 - accuracy: 0.6565 - val_loss: 1.2667 - val_accuracy: 0.5460
# Epoch 48/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9685 - accuracy: 0.6558
# Epoch 48: val_accuracy did not improve from 0.54599
# 181/181 [==============================] - 48s 266ms/step - loss: 0.9685 - accuracy: 0.6558 - val_loss: 1.2902 - val_accuracy: 0.5381
# Epoch 49/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9671 - accuracy: 0.6568
# Epoch 49: val_accuracy did not improve from 0.54599
# 181/181 [==============================] - 48s 265ms/step - loss: 0.9671 - accuracy: 0.6568 - val_loss: 1.2968 - val_accuracy: 0.5387
# Epoch 50/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9649 - accuracy: 0.6600
# Epoch 50: val_accuracy did not improve from 0.54599
# 181/181 [==============================] - 47s 257ms/step - loss: 0.9649 - accuracy: 0.6600 - val_loss: 1.2831 - val_accuracy: 0.5446
# Epoch 51/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9604 - accuracy: 0.6578
# Epoch 51: val_accuracy did not improve from 0.54599
# 181/181 [==============================] - 47s 260ms/step - loss: 0.9604 - accuracy: 0.6578 - val_loss: 1.2949 - val_accuracy: 0.5440
# Epoch 52/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9597 - accuracy: 0.6595
# Epoch 52: val_accuracy improved from 0.54599 to 0.55214, saving model to model_weights2.h5
# 181/181 [==============================] - 50s 275ms/step - loss: 0.9597 - accuracy: 0.6595 - val_loss: 1.2623 - val_accuracy: 0.5521
# Epoch 53/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9561 - accuracy: 0.6612
# Epoch 53: val_accuracy improved from 0.55214 to 0.55540, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 255ms/step - loss: 0.9561 - accuracy: 0.6612 - val_loss: 1.2411 - val_accuracy: 0.5554
# Epoch 54/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9529 - accuracy: 0.6637
# Epoch 54: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 257ms/step - loss: 0.9529 - accuracy: 0.6637 - val_loss: 1.2555 - val_accuracy: 0.5498
# Epoch 55/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9505 - accuracy: 0.6619
# Epoch 55: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 257ms/step - loss: 0.9505 - accuracy: 0.6619 - val_loss: 1.2858 - val_accuracy: 0.5457
# Epoch 56/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9451 - accuracy: 0.6636
# Epoch 56: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 256ms/step - loss: 0.9451 - accuracy: 0.6636 - val_loss: 1.2538 - val_accuracy: 0.5539
# Epoch 57/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9467 - accuracy: 0.6649
# Epoch 57: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 254ms/step - loss: 0.9467 - accuracy: 0.6649 - val_loss: 1.2904 - val_accuracy: 0.5426
# Epoch 58/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9395 - accuracy: 0.6653
# Epoch 58: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 257ms/step - loss: 0.9395 - accuracy: 0.6653 - val_loss: 1.2787 - val_accuracy: 0.5499
# Epoch 59/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9396 - accuracy: 0.6662
# Epoch 59: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 259ms/step - loss: 0.9396 - accuracy: 0.6662 - val_loss: 1.2988 - val_accuracy: 0.5423
# Epoch 60/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9370 - accuracy: 0.6681
# Epoch 60: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 259ms/step - loss: 0.9370 - accuracy: 0.6681 - val_loss: 1.2973 - val_accuracy: 0.5421
# Epoch 61/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9340 - accuracy: 0.6683
# Epoch 61: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 257ms/step - loss: 0.9340 - accuracy: 0.6683 - val_loss: 1.2957 - val_accuracy: 0.5446
# Epoch 62/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9318 - accuracy: 0.6695
# Epoch 62: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 255ms/step - loss: 0.9318 - accuracy: 0.6695 - val_loss: 1.2674 - val_accuracy: 0.5510
# Epoch 63/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9277 - accuracy: 0.6700
# Epoch 63: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 256ms/step - loss: 0.9277 - accuracy: 0.6700 - val_loss: 1.2790 - val_accuracy: 0.5468
# Epoch 64/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9277 - accuracy: 0.6717
# Epoch 64: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 259ms/step - loss: 0.9277 - accuracy: 0.6717 - val_loss: 1.2732 - val_accuracy: 0.5497
# Epoch 65/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9249 - accuracy: 0.6724
# Epoch 65: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 255ms/step - loss: 0.9249 - accuracy: 0.6724 - val_loss: 1.2650 - val_accuracy: 0.5520
# Epoch 66/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9227 - accuracy: 0.6723
# Epoch 66: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 257ms/step - loss: 0.9227 - accuracy: 0.6723 - val_loss: 1.2884 - val_accuracy: 0.5442
# Epoch 67/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9185 - accuracy: 0.6741
# Epoch 67: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 259ms/step - loss: 0.9185 - accuracy: 0.6741 - val_loss: 1.2927 - val_accuracy: 0.5452
# Epoch 68/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9175 - accuracy: 0.6740
# Epoch 68: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 256ms/step - loss: 0.9175 - accuracy: 0.6740 - val_loss: 1.3025 - val_accuracy: 0.5429
# Epoch 69/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9142 - accuracy: 0.6768
# Epoch 69: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 261ms/step - loss: 0.9142 - accuracy: 0.6768 - val_loss: 1.3022 - val_accuracy: 0.5437
# Epoch 70/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9140 - accuracy: 0.6765
# Epoch 70: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 257ms/step - loss: 0.9140 - accuracy: 0.6765 - val_loss: 1.2966 - val_accuracy: 0.5453
# Epoch 71/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9121 - accuracy: 0.6772
# Epoch 71: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 255ms/step - loss: 0.9121 - accuracy: 0.6772 - val_loss: 1.2813 - val_accuracy: 0.5475
# Epoch 72/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9069 - accuracy: 0.6783
# Epoch 72: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 258ms/step - loss: 0.9069 - accuracy: 0.6783 - val_loss: 1.2540 - val_accuracy: 0.5542
# Epoch 73/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9088 - accuracy: 0.6777
# Epoch 73: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 255ms/step - loss: 0.9088 - accuracy: 0.6777 - val_loss: 1.2762 - val_accuracy: 0.5468
# Epoch 74/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9051 - accuracy: 0.6794
# Epoch 74: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 253ms/step - loss: 0.9051 - accuracy: 0.6794 - val_loss: 1.2602 - val_accuracy: 0.5533
# Epoch 75/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9035 - accuracy: 0.6802
# Epoch 75: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 46s 256ms/step - loss: 0.9035 - accuracy: 0.6802 - val_loss: 1.2892 - val_accuracy: 0.5456
# Epoch 76/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9009 - accuracy: 0.6811
# Epoch 76: val_accuracy did not improve from 0.55540
# 181/181 [==============================] - 47s 259ms/step - loss: 0.9009 - accuracy: 0.6811 - val_loss: 1.2890 - val_accuracy: 0.5462
# Epoch 77/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8968 - accuracy: 0.6834
# Epoch 77: val_accuracy improved from 0.55540 to 0.55634, saving model to model_weights2.h5
# 181/181 [==============================] - 46s 255ms/step - loss: 0.8968 - accuracy: 0.6834 - val_loss: 1.2591 - val_accuracy: 0.5563
# Epoch 78/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8943 - accuracy: 0.6828
# Epoch 78: val_accuracy did not improve from 0.55634
# 181/181 [==============================] - 47s 259ms/step - loss: 0.8943 - accuracy: 0.6828 - val_loss: 1.2926 - val_accuracy: 0.5463
# Epoch 79/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8934 - accuracy: 0.6838
# Epoch 79: val_accuracy did not improve from 0.55634
# 181/181 [==============================] - 46s 255ms/step - loss: 0.8934 - accuracy: 0.6838 - val_loss: 1.2743 - val_accuracy: 0.5492
# Epoch 80/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8900 - accuracy: 0.6838
# Epoch 80: val_accuracy did not improve from 0.55634
# 181/181 [==============================] - 47s 258ms/step - loss: 0.8900 - accuracy: 0.6838 - val_loss: 1.2725 - val_accuracy: 0.5475
# Epoch 81/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8901 - accuracy: 0.6836
# Epoch 81: val_accuracy did not improve from 0.55634
# 181/181 [==============================] - 47s 258ms/step - loss: 0.8901 - accuracy: 0.6836 - val_loss: 1.2795 - val_accuracy: 0.5497
# Epoch 82/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8871 - accuracy: 0.6850
# Epoch 82: val_accuracy improved from 0.55634 to 0.55990, saving model to model_weights2.h5
# 181/181 [==============================] - 47s 258ms/step - loss: 0.8871 - accuracy: 0.6850 - val_loss: 1.2445 - val_accuracy: 0.5599
# Epoch 83/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8842 - accuracy: 0.6867
# Epoch 83: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 47s 257ms/step - loss: 0.8842 - accuracy: 0.6867 - val_loss: 1.2975 - val_accuracy: 0.5494
# Epoch 84/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8834 - accuracy: 0.6857
# Epoch 84: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 46s 256ms/step - loss: 0.8834 - accuracy: 0.6857 - val_loss: 1.2800 - val_accuracy: 0.5537
# Epoch 85/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8820 - accuracy: 0.6883
# Epoch 85: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 47s 259ms/step - loss: 0.8820 - accuracy: 0.6883 - val_loss: 1.2882 - val_accuracy: 0.5513
# Epoch 86/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8795 - accuracy: 0.6886
# Epoch 86: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 47s 258ms/step - loss: 0.8795 - accuracy: 0.6886 - val_loss: 1.2856 - val_accuracy: 0.5513
# Epoch 87/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8783 - accuracy: 0.6879
# Epoch 87: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 47s 258ms/step - loss: 0.8783 - accuracy: 0.6879 - val_loss: 1.2663 - val_accuracy: 0.5547
# Epoch 88/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8746 - accuracy: 0.6888
# Epoch 88: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 46s 253ms/step - loss: 0.8746 - accuracy: 0.6888 - val_loss: 1.2846 - val_accuracy: 0.5543
# Epoch 89/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8736 - accuracy: 0.6903
# Epoch 89: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 46s 255ms/step - loss: 0.8736 - accuracy: 0.6903 - val_loss: 1.2545 - val_accuracy: 0.5596
# Epoch 90/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8683 - accuracy: 0.6910
# Epoch 90: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 47s 259ms/step - loss: 0.8683 - accuracy: 0.6910 - val_loss: 1.2812 - val_accuracy: 0.5520
# Epoch 91/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8703 - accuracy: 0.6916
# Epoch 91: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 46s 257ms/step - loss: 0.8703 - accuracy: 0.6916 - val_loss: 1.2683 - val_accuracy: 0.5569
# Epoch 92/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8685 - accuracy: 0.6923
# Epoch 92: val_accuracy did not improve from 0.55990
# 181/181 [==============================] - 47s 258ms/step - loss: 0.8685 - accuracy: 0.6923 - val_loss: 1.2812 - val_accuracy: 0.5516
# Epoch 93/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8678 - accuracy: 0.6906
# Epoch 93: val_accuracy improved from 0.55990 to 0.56570, saving model to model_weights2.h5
# 181/181 [==============================] - 48s 263ms/step - loss: 0.8678 - accuracy: 0.6906 - val_loss: 1.2351 - val_accuracy: 0.5657
# Epoch 94/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8617 - accuracy: 0.6938
# Epoch 94: val_accuracy did not improve from 0.56570
# 181/181 [==============================] - 49s 272ms/step - loss: 0.8617 - accuracy: 0.6938 - val_loss: 1.2991 - val_accuracy: 0.5468
# Epoch 95/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8622 - accuracy: 0.6943
# Epoch 95: val_accuracy did not improve from 0.56570
# 181/181 [==============================] - 48s 265ms/step - loss: 0.8622 - accuracy: 0.6943 - val_loss: 1.2389 - val_accuracy: 0.5647
# Epoch 96/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8607 - accuracy: 0.6944
# Epoch 96: val_accuracy did not improve from 0.56570
# 181/181 [==============================] - 48s 264ms/step - loss: 0.8607 - accuracy: 0.6944 - val_loss: 1.2824 - val_accuracy: 0.5510
# Epoch 97/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8602 - accuracy: 0.6946
# Epoch 97: val_accuracy did not improve from 0.56570
# 181/181 [==============================] - 47s 262ms/step - loss: 0.8602 - accuracy: 0.6946 - val_loss: 1.2867 - val_accuracy: 0.5549
# Epoch 98/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8571 - accuracy: 0.6953
# Epoch 98: val_accuracy did not improve from 0.56570
# 181/181 [==============================] - 48s 264ms/step - loss: 0.8571 - accuracy: 0.6953 - val_loss: 1.2451 - val_accuracy: 0.5616
# Epoch 99/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8548 - accuracy: 0.6965
# Epoch 99: val_accuracy did not improve from 0.56570
# 181/181 [==============================] - 47s 262ms/step - loss: 0.8548 - accuracy: 0.6965 - val_loss: 1.2718 - val_accuracy: 0.5532
# Epoch 100/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8501 - accuracy: 0.6991
# Epoch 100: val_accuracy did not improve from 0.56570
# 181/181 [==============================] - 47s 260ms/step - loss: 0.8501 - accuracy: 0.6991 - val_loss: 1.2641 - val_accuracy: 0.5600

# %%
# NOT CHANGED! # DO NOT USE LIKE THIS
model.save_weights("./model2.h5")

# %%
# NOT CHANGED # DO NOT USE LIKE THIS!
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
