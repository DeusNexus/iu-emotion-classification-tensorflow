# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, MaxPooling2D, BatchNormalization, Conv2D, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# 2023-12-20 13:07:58.683424: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-20 13:07:59.345135: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Image Specifications
folder_path = "../dataset/MMAFEDB/"
image_dimension = (48, 48)
image_depth = 1
image_color_mode = 'grayscale'
batch_size = 512

# Data Augmentation for Training Set
datagen_train = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Only rescaling for Validation Set
datagen_val = ImageDataGenerator(rescale=1./255)

train_set = datagen_train.flow_from_directory(
    folder_path + "train",
    target_size=image_dimension,
    color_mode=image_color_mode,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

test_set = datagen_val.flow_from_directory(
    folder_path + "valid",
    target_size=image_dimension,
    color_mode=image_color_mode,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Get the total number of images in the training set
total_images_train = train_set.n
print("Total images in training set:", total_images_train)
# Get the total number of images in the training set
total_images_test = test_set.n
print("Total images in test set:", total_images_test)
# Out:
# Found 92968 images belonging to 7 classes.
# Found 17356 images belonging to 7 classes.
# Total images in training set: 92968
# Total images in test set: 17356

# %%
drop_rate = 0.3

# Create sequential model
model = Sequential()

model.add(Conv2D(32, kernel_size=3, activation="relu", input_shape=(48, 48, image_depth), padding="same"))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=3, activation="relu", input_shape=(48, 48, image_depth), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2)) # 48 x 48 -> 24 x 24
model.add(Dropout(drop_rate))

model.add(Conv2D(128, kernel_size=3, activation="relu"))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size=3, activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2)) # 24 x 24 -> 12 x 12
model.add(Dropout(drop_rate))

model.add(Conv2D(256, kernel_size=3, activation="relu"))
model.add(BatchNormalization())
model.add(Conv2D(256, kernel_size=3, activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2)) # 12 x 12 -> 6 x 6
model.add(Dropout(drop_rate))

#????
model.add(Conv2D(512, kernel_size=3, activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(1)) # 6 x 6 -> 3 x 3
model.add(Dropout(drop_rate))

# Flatten before fully connected layers
model.add(Flatten())
# Fully Connected Layer + ReLU
model.add(Dense(1024, activation="relu", use_bias=False))
model.add(BatchNormalization())
model.add(Dropout(drop_rate))

# Final Output Layer with Softmax 
model.add(Dense(7,activation='softmax'))

# ###########
# Model 2
# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', 
#                          input_shape=(48, 48, 3)))
# model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
 
# model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Flatten())
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# ###########

initial_learning_rate = 0.0001
lr_schedule = ExponentialDecay(initial_learning_rate, decay_steps=100000, decay_rate=0.96)
optimizer_adam = Adam(learning_rate=lr_schedule)

# Compile model
model.compile(
    optimizer=optimizer_adam,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  batch_normalization (Batch  (None, 48, 48, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 48, 48, 64)        256
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 22, 22, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 22, 22, 128)       512
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 20, 20, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 6, 6, 256)         590080
#
#  batch_normalization_5 (Bat  (None, 6, 6, 256)         1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 3, 3, 256)         0
#
#  conv2d_6 (Conv2D)           (None, 1, 1, 512)         1180160
#
#  batch_normalization_6 (Bat  (None, 1, 1, 512)         2048
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 1, 1, 512)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              524288
#
#  batch_normalization_7 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 2846727 (10.86 MB)
# Trainable params: 2841927 (10.84 MB)
# Non-trainable params: 4800 (18.75 KB)
# _________________________________________________________________
# 2023-12-20 13:08:02.062038: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 13:08:02.087754: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 13:08:02.088002: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 13:08:02.089115: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 13:08:02.089321: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 13:08:02.089502: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 13:08:02.570037: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 13:08:02.570332: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 13:08:02.570561: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 13:08:02.570737: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3580 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Define hyperparameters
epochs = 100

# Set up model checkpoint
checkpoint = ModelCheckpoint(
    "model_weights2.h5",
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max'
)
callbacks_list = [checkpoint]

# Train the model
history = model.fit(
    train_set,
    validation_data=test_set,
    steps_per_epoch=total_images_train // batch_size,
    validation_steps=total_images_test // batch_size,
    epochs=epochs,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/100
# 2023-12-20 13:08:04.272282: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-12-20 13:08:05.502118: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2023-12-20 13:08:06.947121: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-20 13:08:06.949845: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55786fe99b60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-20 13:08:06.949879: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2023-12-20 13:08:06.955942: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-20 13:08:07.058619: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 181/181 [==============================] - ETA: 0s - loss: 2.2844 - accuracy: 0.2638
# Epoch 1: val_accuracy improved from -inf to 0.31546, saving model to model_weights2.h5
# 181/181 [==============================] - 51s 201ms/step - loss: 2.2844 - accuracy: 0.2638 - val_loss: 1.7522 - val_accuracy: 0.3155
# Epoch 2/100
# /home/fox/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 181/181 [==============================] - ETA: 0s - loss: 1.8894 - accuracy: 0.3696
# Epoch 2: val_accuracy improved from 0.31546 to 0.32901, saving model to model_weights2.h5
# 181/181 [==============================] - 32s 175ms/step - loss: 1.8894 - accuracy: 0.3696 - val_loss: 1.8110 - val_accuracy: 0.3290
# Epoch 3/100
# 181/181 [==============================] - ETA: 0s - loss: 1.7145 - accuracy: 0.4206
# Epoch 3: val_accuracy improved from 0.32901 to 0.36624, saving model to model_weights2.h5
# 181/181 [==============================] - 32s 173ms/step - loss: 1.7145 - accuracy: 0.4206 - val_loss: 1.8062 - val_accuracy: 0.3662
# Epoch 4/100
# 181/181 [==============================] - ETA: 0s - loss: 1.6129 - accuracy: 0.4512
# Epoch 4: val_accuracy improved from 0.36624 to 0.44235, saving model to model_weights2.h5
# 181/181 [==============================] - 32s 174ms/step - loss: 1.6129 - accuracy: 0.4512 - val_loss: 1.5306 - val_accuracy: 0.4424
# Epoch 5/100
# 181/181 [==============================] - ETA: 0s - loss: 1.5347 - accuracy: 0.4738
# Epoch 5: val_accuracy improved from 0.44235 to 0.45768, saving model to model_weights2.h5
# 181/181 [==============================] - 32s 176ms/step - loss: 1.5347 - accuracy: 0.4738 - val_loss: 1.5182 - val_accuracy: 0.4577
# Epoch 6/100
# 181/181 [==============================] - ETA: 0s - loss: 1.4797 - accuracy: 0.4910
# Epoch 6: val_accuracy improved from 0.45768 to 0.46632, saving model to model_weights2.h5
# 181/181 [==============================] - 32s 174ms/step - loss: 1.4797 - accuracy: 0.4910 - val_loss: 1.4740 - val_accuracy: 0.4663
# Epoch 7/100
# 181/181 [==============================] - ETA: 0s - loss: 1.4301 - accuracy: 0.5043
# Epoch 7: val_accuracy improved from 0.46632 to 0.47195, saving model to model_weights2.h5
# 181/181 [==============================] - 32s 175ms/step - loss: 1.4301 - accuracy: 0.5043 - val_loss: 1.4685 - val_accuracy: 0.4719
# Epoch 8/100
# 181/181 [==============================] - ETA: 0s - loss: 1.3786 - accuracy: 0.5216
# Epoch 8: val_accuracy did not improve from 0.47195
# 181/181 [==============================] - 32s 175ms/step - loss: 1.3786 - accuracy: 0.5216 - val_loss: 1.4748 - val_accuracy: 0.4703
# Epoch 9/100
# 181/181 [==============================] - ETA: 0s - loss: 1.3403 - accuracy: 0.5336
# Epoch 9: val_accuracy improved from 0.47195 to 0.47212, saving model to model_weights2.h5
# 181/181 [==============================] - 32s 174ms/step - loss: 1.3403 - accuracy: 0.5336 - val_loss: 1.4888 - val_accuracy: 0.4721
# Epoch 10/100
# 181/181 [==============================] - ETA: 0s - loss: 1.3033 - accuracy: 0.5447
# Epoch 10: val_accuracy improved from 0.47212 to 0.48029, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 171ms/step - loss: 1.3033 - accuracy: 0.5447 - val_loss: 1.4596 - val_accuracy: 0.4803
# Epoch 11/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2699 - accuracy: 0.5544
# Epoch 11: val_accuracy improved from 0.48029 to 0.48295, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 168ms/step - loss: 1.2699 - accuracy: 0.5544 - val_loss: 1.4595 - val_accuracy: 0.4830
# Epoch 12/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2330 - accuracy: 0.5675
# Epoch 12: val_accuracy improved from 0.48295 to 0.49592, saving model to model_weights2.h5
# 181/181 [==============================] - 30s 167ms/step - loss: 1.2330 - accuracy: 0.5675 - val_loss: 1.4200 - val_accuracy: 0.4959
# Epoch 13/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2085 - accuracy: 0.5740
# Epoch 13: val_accuracy did not improve from 0.49592
# 181/181 [==============================] - 30s 167ms/step - loss: 1.2085 - accuracy: 0.5740 - val_loss: 1.4354 - val_accuracy: 0.4918
# Epoch 14/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1858 - accuracy: 0.5843
# Epoch 14: val_accuracy improved from 0.49592 to 0.50089, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 169ms/step - loss: 1.1858 - accuracy: 0.5843 - val_loss: 1.4165 - val_accuracy: 0.5009
# Epoch 15/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1622 - accuracy: 0.5916
# Epoch 15: val_accuracy did not improve from 0.50089
# 181/181 [==============================] - 31s 168ms/step - loss: 1.1622 - accuracy: 0.5916 - val_loss: 1.4489 - val_accuracy: 0.4894
# Epoch 16/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1470 - accuracy: 0.5970
# Epoch 16: val_accuracy improved from 0.50089 to 0.51071, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 170ms/step - loss: 1.1470 - accuracy: 0.5970 - val_loss: 1.4053 - val_accuracy: 0.5107
# Epoch 17/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1305 - accuracy: 0.6021
# Epoch 17: val_accuracy did not improve from 0.51071
# 181/181 [==============================] - 31s 168ms/step - loss: 1.1305 - accuracy: 0.6021 - val_loss: 1.3879 - val_accuracy: 0.5070
# Epoch 18/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1144 - accuracy: 0.6101
# Epoch 18: val_accuracy improved from 0.51071 to 0.51409, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 168ms/step - loss: 1.1144 - accuracy: 0.6101 - val_loss: 1.3811 - val_accuracy: 0.5141
# Epoch 19/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1025 - accuracy: 0.6121
# Epoch 19: val_accuracy improved from 0.51409 to 0.51894, saving model to model_weights2.h5
# 181/181 [==============================] - 30s 167ms/step - loss: 1.1025 - accuracy: 0.6121 - val_loss: 1.3642 - val_accuracy: 0.5189
# Epoch 20/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0873 - accuracy: 0.6176
# Epoch 20: val_accuracy improved from 0.51894 to 0.52255, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 169ms/step - loss: 1.0873 - accuracy: 0.6176 - val_loss: 1.3617 - val_accuracy: 0.5225
# Epoch 21/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0761 - accuracy: 0.6217
# Epoch 21: val_accuracy did not improve from 0.52255
# 181/181 [==============================] - 30s 166ms/step - loss: 1.0761 - accuracy: 0.6217 - val_loss: 1.3884 - val_accuracy: 0.5144
# Epoch 22/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0649 - accuracy: 0.6260
# Epoch 22: val_accuracy did not improve from 0.52255
# 181/181 [==============================] - 30s 166ms/step - loss: 1.0649 - accuracy: 0.6260 - val_loss: 1.3817 - val_accuracy: 0.5165
# Epoch 23/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0569 - accuracy: 0.6274
# Epoch 23: val_accuracy did not improve from 0.52255
# 181/181 [==============================] - 30s 167ms/step - loss: 1.0569 - accuracy: 0.6274 - val_loss: 1.4062 - val_accuracy: 0.5119
# Epoch 24/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0468 - accuracy: 0.6309
# Epoch 24: val_accuracy did not improve from 0.52255
# 181/181 [==============================] - 31s 169ms/step - loss: 1.0468 - accuracy: 0.6309 - val_loss: 1.3758 - val_accuracy: 0.5182
# Epoch 25/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0380 - accuracy: 0.6351
# Epoch 25: val_accuracy did not improve from 0.52255
# 181/181 [==============================] - 30s 166ms/step - loss: 1.0380 - accuracy: 0.6351 - val_loss: 1.3833 - val_accuracy: 0.5195
# Epoch 26/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0304 - accuracy: 0.6378
# Epoch 26: val_accuracy improved from 0.52255 to 0.53900, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 171ms/step - loss: 1.0304 - accuracy: 0.6378 - val_loss: 1.3379 - val_accuracy: 0.5390
# Epoch 27/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0222 - accuracy: 0.6421
# Epoch 27: val_accuracy did not improve from 0.53900
# 181/181 [==============================] - 31s 169ms/step - loss: 1.0222 - accuracy: 0.6421 - val_loss: 1.3838 - val_accuracy: 0.5252
# Epoch 28/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0155 - accuracy: 0.6428
# Epoch 28: val_accuracy did not improve from 0.53900
# 181/181 [==============================] - 31s 169ms/step - loss: 1.0155 - accuracy: 0.6428 - val_loss: 1.3825 - val_accuracy: 0.5185
# Epoch 29/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0045 - accuracy: 0.6469
# Epoch 29: val_accuracy did not improve from 0.53900
# 181/181 [==============================] - 31s 172ms/step - loss: 1.0045 - accuracy: 0.6469 - val_loss: 1.4028 - val_accuracy: 0.5172
# Epoch 30/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9989 - accuracy: 0.6490
# Epoch 30: val_accuracy improved from 0.53900 to 0.54096, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 171ms/step - loss: 0.9989 - accuracy: 0.6490 - val_loss: 1.3067 - val_accuracy: 0.5410
# Epoch 31/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9906 - accuracy: 0.6510
# Epoch 31: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 31s 171ms/step - loss: 0.9906 - accuracy: 0.6510 - val_loss: 1.3486 - val_accuracy: 0.5241
# Epoch 32/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9811 - accuracy: 0.6546
# Epoch 32: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 30s 166ms/step - loss: 0.9811 - accuracy: 0.6546 - val_loss: 1.3198 - val_accuracy: 0.5388
# Epoch 33/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9754 - accuracy: 0.6568
# Epoch 33: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 31s 170ms/step - loss: 0.9754 - accuracy: 0.6568 - val_loss: 1.3619 - val_accuracy: 0.5301
# Epoch 34/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9707 - accuracy: 0.6571
# Epoch 34: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 31s 170ms/step - loss: 0.9707 - accuracy: 0.6571 - val_loss: 1.3292 - val_accuracy: 0.5348
# Epoch 35/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9633 - accuracy: 0.6615
# Epoch 35: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 31s 168ms/step - loss: 0.9633 - accuracy: 0.6615 - val_loss: 1.3380 - val_accuracy: 0.5305
# Epoch 36/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9577 - accuracy: 0.6633
# Epoch 36: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 31s 169ms/step - loss: 0.9577 - accuracy: 0.6633 - val_loss: 1.3400 - val_accuracy: 0.5356
# Epoch 37/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9492 - accuracy: 0.6654
# Epoch 37: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 31s 169ms/step - loss: 0.9492 - accuracy: 0.6654 - val_loss: 1.3489 - val_accuracy: 0.5353
# Epoch 38/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9439 - accuracy: 0.6677
# Epoch 38: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 31s 168ms/step - loss: 0.9439 - accuracy: 0.6677 - val_loss: 1.3306 - val_accuracy: 0.5400
# Epoch 39/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9403 - accuracy: 0.6685
# Epoch 39: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 30s 167ms/step - loss: 0.9403 - accuracy: 0.6685 - val_loss: 1.3545 - val_accuracy: 0.5272
# Epoch 40/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9345 - accuracy: 0.6698
# Epoch 40: val_accuracy did not improve from 0.54096
# 181/181 [==============================] - 31s 171ms/step - loss: 0.9345 - accuracy: 0.6698 - val_loss: 1.3468 - val_accuracy: 0.5326
# Epoch 41/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9275 - accuracy: 0.6726
# Epoch 41: val_accuracy improved from 0.54096 to 0.54392, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 169ms/step - loss: 0.9275 - accuracy: 0.6726 - val_loss: 1.3280 - val_accuracy: 0.5439
# Epoch 42/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9229 - accuracy: 0.6729
# Epoch 42: val_accuracy did not improve from 0.54392
# 181/181 [==============================] - 31s 168ms/step - loss: 0.9229 - accuracy: 0.6729 - val_loss: 1.3394 - val_accuracy: 0.5382
# Epoch 43/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9151 - accuracy: 0.6789
# Epoch 43: val_accuracy did not improve from 0.54392
# 181/181 [==============================] - 31s 170ms/step - loss: 0.9151 - accuracy: 0.6789 - val_loss: 1.3430 - val_accuracy: 0.5387
# Epoch 44/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9140 - accuracy: 0.6772
# Epoch 44: val_accuracy improved from 0.54392 to 0.55025, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 172ms/step - loss: 0.9140 - accuracy: 0.6772 - val_loss: 1.3168 - val_accuracy: 0.5502
# Epoch 45/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9056 - accuracy: 0.6807
# Epoch 45: val_accuracy did not improve from 0.55025
# 181/181 [==============================] - 31s 170ms/step - loss: 0.9056 - accuracy: 0.6807 - val_loss: 1.3248 - val_accuracy: 0.5489
# Epoch 46/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9029 - accuracy: 0.6819
# Epoch 46: val_accuracy improved from 0.55025 to 0.55374, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 171ms/step - loss: 0.9029 - accuracy: 0.6819 - val_loss: 1.2917 - val_accuracy: 0.5537
# Epoch 47/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8949 - accuracy: 0.6838
# Epoch 47: val_accuracy did not improve from 0.55374
# 181/181 [==============================] - 31s 171ms/step - loss: 0.8949 - accuracy: 0.6838 - val_loss: 1.2921 - val_accuracy: 0.5536
# Epoch 48/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8940 - accuracy: 0.6837
# Epoch 48: val_accuracy did not improve from 0.55374
# 181/181 [==============================] - 31s 170ms/step - loss: 0.8940 - accuracy: 0.6837 - val_loss: 1.3160 - val_accuracy: 0.5443
# Epoch 49/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8895 - accuracy: 0.6850
# Epoch 49: val_accuracy did not improve from 0.55374
# 181/181 [==============================] - 31s 170ms/step - loss: 0.8895 - accuracy: 0.6850 - val_loss: 1.3406 - val_accuracy: 0.5419
# Epoch 50/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8824 - accuracy: 0.6886
# Epoch 50: val_accuracy did not improve from 0.55374
# 181/181 [==============================] - 31s 168ms/step - loss: 0.8824 - accuracy: 0.6886 - val_loss: 1.2879 - val_accuracy: 0.5537
# Epoch 51/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8809 - accuracy: 0.6887
# Epoch 51: val_accuracy improved from 0.55374 to 0.56031, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 171ms/step - loss: 0.8809 - accuracy: 0.6887 - val_loss: 1.2630 - val_accuracy: 0.5603
# Epoch 52/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8765 - accuracy: 0.6899
# Epoch 52: val_accuracy did not improve from 0.56031
# 181/181 [==============================] - 31s 171ms/step - loss: 0.8765 - accuracy: 0.6899 - val_loss: 1.3105 - val_accuracy: 0.5511
# Epoch 53/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8699 - accuracy: 0.6925
# Epoch 53: val_accuracy improved from 0.56031 to 0.56499, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 171ms/step - loss: 0.8699 - accuracy: 0.6925 - val_loss: 1.2804 - val_accuracy: 0.5650
# Epoch 54/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8672 - accuracy: 0.6934
# Epoch 54: val_accuracy did not improve from 0.56499
# 181/181 [==============================] - 31s 168ms/step - loss: 0.8672 - accuracy: 0.6934 - val_loss: 1.3240 - val_accuracy: 0.5507
# Epoch 55/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8617 - accuracy: 0.6964
# Epoch 55: val_accuracy improved from 0.56499 to 0.56812, saving model to model_weights2.h5
# 181/181 [==============================] - 31s 170ms/step - loss: 0.8617 - accuracy: 0.6964 - val_loss: 1.2646 - val_accuracy: 0.5681
# Epoch 56/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8601 - accuracy: 0.6951
# Epoch 56: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.8601 - accuracy: 0.6951 - val_loss: 1.3364 - val_accuracy: 0.5469
# Epoch 57/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8542 - accuracy: 0.6974
# Epoch 57: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.8542 - accuracy: 0.6974 - val_loss: 1.3047 - val_accuracy: 0.5539
# Epoch 58/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8498 - accuracy: 0.6987
# Epoch 58: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 171ms/step - loss: 0.8498 - accuracy: 0.6987 - val_loss: 1.2897 - val_accuracy: 0.5592
# Epoch 59/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8505 - accuracy: 0.7000
# Epoch 59: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.8505 - accuracy: 0.7000 - val_loss: 1.3169 - val_accuracy: 0.5529
# Epoch 60/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8432 - accuracy: 0.7029
# Epoch 60: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 171ms/step - loss: 0.8432 - accuracy: 0.7029 - val_loss: 1.3188 - val_accuracy: 0.5570
# Epoch 61/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8379 - accuracy: 0.7035
# Epoch 61: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 171ms/step - loss: 0.8379 - accuracy: 0.7035 - val_loss: 1.3226 - val_accuracy: 0.5536
# Epoch 62/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8341 - accuracy: 0.7043
# Epoch 62: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.8341 - accuracy: 0.7043 - val_loss: 1.3215 - val_accuracy: 0.5552
# Epoch 63/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8323 - accuracy: 0.7049
# Epoch 63: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 172ms/step - loss: 0.8323 - accuracy: 0.7049 - val_loss: 1.3207 - val_accuracy: 0.5564
# Epoch 64/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8288 - accuracy: 0.7084
# Epoch 64: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.8288 - accuracy: 0.7084 - val_loss: 1.3062 - val_accuracy: 0.5608
# Epoch 65/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8249 - accuracy: 0.7081
# Epoch 65: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 168ms/step - loss: 0.8249 - accuracy: 0.7081 - val_loss: 1.3076 - val_accuracy: 0.5600
# Epoch 66/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8193 - accuracy: 0.7093
# Epoch 66: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.8193 - accuracy: 0.7093 - val_loss: 1.3376 - val_accuracy: 0.5550
# Epoch 67/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8167 - accuracy: 0.7098
# Epoch 67: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.8167 - accuracy: 0.7098 - val_loss: 1.3276 - val_accuracy: 0.5500
# Epoch 68/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8148 - accuracy: 0.7106
# Epoch 68: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.8148 - accuracy: 0.7106 - val_loss: 1.2917 - val_accuracy: 0.5672
# Epoch 69/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8114 - accuracy: 0.7115
# Epoch 69: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.8114 - accuracy: 0.7115 - val_loss: 1.3161 - val_accuracy: 0.5561
# Epoch 70/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8076 - accuracy: 0.7111
# Epoch 70: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.8076 - accuracy: 0.7111 - val_loss: 1.3752 - val_accuracy: 0.5442
# Epoch 71/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8035 - accuracy: 0.7150
# Epoch 71: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 168ms/step - loss: 0.8035 - accuracy: 0.7150 - val_loss: 1.3081 - val_accuracy: 0.5643
# Epoch 72/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8003 - accuracy: 0.7159
# Epoch 72: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 173ms/step - loss: 0.8003 - accuracy: 0.7159 - val_loss: 1.3522 - val_accuracy: 0.5505
# Epoch 73/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7954 - accuracy: 0.7172
# Epoch 73: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.7954 - accuracy: 0.7172 - val_loss: 1.3513 - val_accuracy: 0.5505
# Epoch 74/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7936 - accuracy: 0.7189
# Epoch 74: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 30s 167ms/step - loss: 0.7936 - accuracy: 0.7189 - val_loss: 1.3445 - val_accuracy: 0.5562
# Epoch 75/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7916 - accuracy: 0.7174
# Epoch 75: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 168ms/step - loss: 0.7916 - accuracy: 0.7174 - val_loss: 1.3553 - val_accuracy: 0.5570
# Epoch 76/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7862 - accuracy: 0.7193
# Epoch 76: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.7862 - accuracy: 0.7193 - val_loss: 1.3449 - val_accuracy: 0.5605
# Epoch 77/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7849 - accuracy: 0.7222
# Epoch 77: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 171ms/step - loss: 0.7849 - accuracy: 0.7222 - val_loss: 1.3100 - val_accuracy: 0.5667
# Epoch 78/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7792 - accuracy: 0.7220
# Epoch 78: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 172ms/step - loss: 0.7792 - accuracy: 0.7220 - val_loss: 1.3633 - val_accuracy: 0.5517
# Epoch 79/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7756 - accuracy: 0.7246
# Epoch 79: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.7756 - accuracy: 0.7246 - val_loss: 1.3103 - val_accuracy: 0.5641
# Epoch 80/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7708 - accuracy: 0.7257
# Epoch 80: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.7708 - accuracy: 0.7257 - val_loss: 1.3391 - val_accuracy: 0.5564
# Epoch 81/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7702 - accuracy: 0.7242
# Epoch 81: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 30s 168ms/step - loss: 0.7702 - accuracy: 0.7242 - val_loss: 1.3155 - val_accuracy: 0.5613
# Epoch 82/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7687 - accuracy: 0.7264
# Epoch 82: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.7687 - accuracy: 0.7264 - val_loss: 1.3359 - val_accuracy: 0.5599
# Epoch 83/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7627 - accuracy: 0.7278
# Epoch 83: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.7627 - accuracy: 0.7278 - val_loss: 1.3390 - val_accuracy: 0.5632
# Epoch 84/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7617 - accuracy: 0.7274
# Epoch 84: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 173ms/step - loss: 0.7617 - accuracy: 0.7274 - val_loss: 1.3679 - val_accuracy: 0.5557
# Epoch 85/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7552 - accuracy: 0.7310
# Epoch 85: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 30s 168ms/step - loss: 0.7552 - accuracy: 0.7310 - val_loss: 1.3602 - val_accuracy: 0.5534
# Epoch 86/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7536 - accuracy: 0.7308
# Epoch 86: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.7536 - accuracy: 0.7308 - val_loss: 1.3917 - val_accuracy: 0.5491
# Epoch 87/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7525 - accuracy: 0.7319
# Epoch 87: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 168ms/step - loss: 0.7525 - accuracy: 0.7319 - val_loss: 1.3814 - val_accuracy: 0.5468
# Epoch 88/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7475 - accuracy: 0.7345
# Epoch 88: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 172ms/step - loss: 0.7475 - accuracy: 0.7345 - val_loss: 1.3656 - val_accuracy: 0.5559
# Epoch 89/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7465 - accuracy: 0.7346
# Epoch 89: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.7465 - accuracy: 0.7346 - val_loss: 1.3372 - val_accuracy: 0.5597
# Epoch 90/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7432 - accuracy: 0.7337
# Epoch 90: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.7432 - accuracy: 0.7337 - val_loss: 1.3906 - val_accuracy: 0.5465
# Epoch 91/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7386 - accuracy: 0.7357
# Epoch 91: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.7386 - accuracy: 0.7357 - val_loss: 1.3736 - val_accuracy: 0.5554
# Epoch 92/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7385 - accuracy: 0.7357
# Epoch 92: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 30s 168ms/step - loss: 0.7385 - accuracy: 0.7357 - val_loss: 1.3831 - val_accuracy: 0.5571
# Epoch 93/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7325 - accuracy: 0.7389
# Epoch 93: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 168ms/step - loss: 0.7325 - accuracy: 0.7389 - val_loss: 1.3809 - val_accuracy: 0.5534
# Epoch 94/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7296 - accuracy: 0.7383
# Epoch 94: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.7296 - accuracy: 0.7383 - val_loss: 1.3887 - val_accuracy: 0.5581
# Epoch 95/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7289 - accuracy: 0.7396
# Epoch 95: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 168ms/step - loss: 0.7289 - accuracy: 0.7396 - val_loss: 1.3810 - val_accuracy: 0.5555
# Epoch 96/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7259 - accuracy: 0.7405
# Epoch 96: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 168ms/step - loss: 0.7259 - accuracy: 0.7405 - val_loss: 1.3756 - val_accuracy: 0.5578
# Epoch 97/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7213 - accuracy: 0.7417
# Epoch 97: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.7213 - accuracy: 0.7417 - val_loss: 1.3665 - val_accuracy: 0.5568
# Epoch 98/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7205 - accuracy: 0.7424
# Epoch 98: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 169ms/step - loss: 0.7205 - accuracy: 0.7424 - val_loss: 1.3516 - val_accuracy: 0.5599
# Epoch 99/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7146 - accuracy: 0.7453
# Epoch 99: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 171ms/step - loss: 0.7146 - accuracy: 0.7453 - val_loss: 1.3981 - val_accuracy: 0.5534
# Epoch 100/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7155 - accuracy: 0.7434
# Epoch 100: val_accuracy did not improve from 0.56812
# 181/181 [==============================] - 31s 170ms/step - loss: 0.7155 - accuracy: 0.7434 - val_loss: 1.3974 - val_accuracy: 0.5518

# %%
# NOT CHANGED! # DO NOT USE LIKE THIS
model.save_weights("./model2.h5")

# %%
# NOT CHANGED # DO NOT USE LIKE THIS!
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
