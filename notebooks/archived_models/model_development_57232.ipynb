# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, MaxPooling2D, BatchNormalization, Conv2D, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# 2023-12-20 08:56:59.999909: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-20 08:57:00.958789: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Image Specifications
folder_path = "../dataset/MMAFEDB/"
image_dimension = (48, 48)
image_depth = 3
image_color_mode = 'rgb'models/model_3_best_nodropout.json
batch_size = 512

# Data Augmentation for Training Set
datagen_train = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Only rescaling for Validation Set
datagen_val = ImageDataGenerator(rescale=1./255)

train_set = datagen_train.flow_from_directory(
    folder_path + "train",
    target_size=image_dimension,
    color_mode=image_color_mode,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

test_set = datagen_val.flow_from_directory(
    folder_path + "valid",
    target_size=image_dimension,
    color_mode=image_color_mode,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Get the total number of images in the training set
total_images_train = train_set.n
print("Total images in training set:", total_images_train)
# Get the total number of images in the training set
total_images_test = test_set.n
print("Total images in test set:", total_images_test)
# Out:
# Found 92968 images belonging to 7 classes.
# Found 17356 images belonging to 7 classes.
# Total images in training set: 92968
# Total images in test set: 17356

# %%
drop_rate = 0.3

# Create sequential model
model = Sequential()

model.add(Conv2D(32, kernel_size=3, activation="relu", input_shape=(48, 48, image_depth), padding="same"))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=3, activation="relu", input_shape=(48, 48, image_depth), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2)) # 48 x 48 -> 24 x 24
model.add(Dropout(drop_rate))

model.add(Conv2D(128, kernel_size=3, activation="relu"))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size=3, activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2)) # 24 x 24 -> 12 x 12
model.add(Dropout(drop_rate))

model.add(Conv2D(256, kernel_size=3, activation="relu"))
model.add(BatchNormalization())
model.add(Conv2D(256, kernel_size=3, activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2)) # 12 x 12 -> 6 x 6
model.add(Dropout(drop_rate))

# Flatten before fully connected layers
model.add(Flatten())
# Fully Connected Layer + ReLU
model.add(Dense(1024, activation="relu", use_bias=False))
model.add(BatchNormalization())
model.add(Dropout(drop_rate))

# Final Output Layer with Softmax 
model.add(Dense(7,activation='softmax'))

initial_learning_rate = 0.0001
lr_schedule = ExponentialDecay(initial_learning_rate, decay_steps=100000, decay_rate=0.96)
optimizer_adam = Adam(learning_rate=lr_schedule)

# Compile model
model.compile(
    optimizer=optimizer_adam,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        896
#
#  batch_normalization (Batch  (None, 48, 48, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 48, 48, 64)        256
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 22, 22, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 22, 22, 128)       512
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 20, 20, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 6, 6, 256)         590080
#
#  batch_normalization_5 (Bat  (None, 6, 6, 256)         1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 3, 3, 256)         0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 1024)              2359296
#
#  batch_normalization_6 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 3500103 (13.35 MB)
# Trainable params: 3496327 (13.34 MB)
# Non-trainable params: 3776 (14.75 KB)
# _________________________________________________________________
# 2023-12-20 08:57:04.246500: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 08:57:04.354731: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 08:57:04.354979: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 08:57:04.356332: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 08:57:04.356530: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 08:57:04.356710: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 08:57:05.108883: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 08:57:05.109107: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 08:57:05.109294: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 08:57:05.109495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3570 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Define hyperparameters
epochs = 100

# Set up model checkpoint
checkpoint = ModelCheckpoint(
    "model_weights.h5",
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max'
)
callbacks_list = [checkpoint]

# Train the model
history = model.fit(
    train_set,
    validation_data=test_set,
    steps_per_epoch=total_images_train // batch_size,
    validation_steps=total_images_test // batch_size,
    epochs=epochs,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/100
# 2023-12-20 08:57:06.835415: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-12-20 08:57:08.687928: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2023-12-20 08:57:10.660869: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-20 08:57:10.675891: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f897c007fc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-20 08:57:10.675916: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2023-12-20 08:57:10.705827: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-20 08:57:10.889113: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 181/181 [==============================] - ETA: 0s - loss: 2.2245 - accuracy: 0.2943
# Epoch 1: val_accuracy improved from -inf to 0.34446, saving model to model_weights.h5
# 181/181 [==============================] - 79s 355ms/step - loss: 2.2245 - accuracy: 0.2943 - val_loss: 1.6800 - val_accuracy: 0.3445
# Epoch 2/100
# /home/fox/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 181/181 [==============================] - ETA: 0s - loss: 1.7978 - accuracy: 0.4005
# Epoch 2: val_accuracy improved from 0.34446 to 0.38210, saving model to model_weights.h5
# 181/181 [==============================] - 48s 264ms/step - loss: 1.7978 - accuracy: 0.4005 - val_loss: 1.6992 - val_accuracy: 0.3821
# Epoch 3/100
# 181/181 [==============================] - ETA: 0s - loss: 1.6321 - accuracy: 0.4463
# Epoch 3: val_accuracy improved from 0.38210 to 0.43123, saving model to model_weights.h5
# 181/181 [==============================] - 49s 270ms/step - loss: 1.6321 - accuracy: 0.4463 - val_loss: 1.5470 - val_accuracy: 0.4312
# Epoch 4/100
# 181/181 [==============================] - ETA: 0s - loss: 1.5324 - accuracy: 0.4732
# Epoch 4: val_accuracy improved from 0.43123 to 0.45638, saving model to model_weights.h5
# 181/181 [==============================] - 48s 266ms/step - loss: 1.5324 - accuracy: 0.4732 - val_loss: 1.4928 - val_accuracy: 0.4564
# Epoch 5/100
# 181/181 [==============================] - ETA: 0s - loss: 1.4591 - accuracy: 0.4922
# Epoch 5: val_accuracy improved from 0.45638 to 0.46881, saving model to model_weights.h5
# 181/181 [==============================] - 49s 271ms/step - loss: 1.4591 - accuracy: 0.4922 - val_loss: 1.4500 - val_accuracy: 0.4688
# Epoch 6/100
# 181/181 [==============================] - ETA: 0s - loss: 1.4055 - accuracy: 0.5105
# Epoch 6: val_accuracy improved from 0.46881 to 0.47408, saving model to model_weights.h5
# 181/181 [==============================] - 48s 267ms/step - loss: 1.4055 - accuracy: 0.5105 - val_loss: 1.4533 - val_accuracy: 0.4741
# Epoch 7/100
# 181/181 [==============================] - ETA: 0s - loss: 1.3515 - accuracy: 0.5260
# Epoch 7: val_accuracy improved from 0.47408 to 0.48414, saving model to model_weights.h5
# 181/181 [==============================] - 48s 264ms/step - loss: 1.3515 - accuracy: 0.5260 - val_loss: 1.4329 - val_accuracy: 0.4841
# Epoch 8/100
# 181/181 [==============================] - ETA: 0s - loss: 1.3158 - accuracy: 0.5377
# Epoch 8: val_accuracy did not improve from 0.48414
# 181/181 [==============================] - 47s 258ms/step - loss: 1.3158 - accuracy: 0.5377 - val_loss: 1.4530 - val_accuracy: 0.4822
# Epoch 9/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2732 - accuracy: 0.5524
# Epoch 9: val_accuracy improved from 0.48414 to 0.49515, saving model to model_weights.h5
# 181/181 [==============================] - 47s 261ms/step - loss: 1.2732 - accuracy: 0.5524 - val_loss: 1.4079 - val_accuracy: 0.4951
# Epoch 10/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2414 - accuracy: 0.5617
# Epoch 10: val_accuracy did not improve from 0.49515
# 181/181 [==============================] - 49s 269ms/step - loss: 1.2414 - accuracy: 0.5617 - val_loss: 1.4132 - val_accuracy: 0.4909
# Epoch 11/100
# 181/181 [==============================] - ETA: 0s - loss: 1.2138 - accuracy: 0.5715
# Epoch 11: val_accuracy improved from 0.49515 to 0.49817, saving model to model_weights.h5
# 181/181 [==============================] - 49s 271ms/step - loss: 1.2138 - accuracy: 0.5715 - val_loss: 1.4180 - val_accuracy: 0.4982
# Epoch 12/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1890 - accuracy: 0.5779
# Epoch 12: val_accuracy improved from 0.49817 to 0.50397, saving model to model_weights.h5
# 181/181 [==============================] - 47s 261ms/step - loss: 1.1890 - accuracy: 0.5779 - val_loss: 1.3944 - val_accuracy: 0.5040
# Epoch 13/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1620 - accuracy: 0.5888
# Epoch 13: val_accuracy did not improve from 0.50397
# 181/181 [==============================] - 47s 259ms/step - loss: 1.1620 - accuracy: 0.5888 - val_loss: 1.4016 - val_accuracy: 0.5036
# Epoch 14/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1389 - accuracy: 0.5980
# Epoch 14: val_accuracy improved from 0.50397 to 0.51255, saving model to model_weights.h5
# 181/181 [==============================] - 48s 263ms/step - loss: 1.1389 - accuracy: 0.5980 - val_loss: 1.3832 - val_accuracy: 0.5125
# Epoch 15/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1204 - accuracy: 0.6022
# Epoch 15: val_accuracy improved from 0.51255 to 0.52515, saving model to model_weights.h5
# 181/181 [==============================] - 47s 262ms/step - loss: 1.1204 - accuracy: 0.6022 - val_loss: 1.3558 - val_accuracy: 0.5252
# Epoch 16/100
# 181/181 [==============================] - ETA: 0s - loss: 1.1029 - accuracy: 0.6097
# Epoch 16: val_accuracy did not improve from 0.52515
# 181/181 [==============================] - 47s 256ms/step - loss: 1.1029 - accuracy: 0.6097 - val_loss: 1.3937 - val_accuracy: 0.5094
# Epoch 17/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0864 - accuracy: 0.6155
# Epoch 17: val_accuracy did not improve from 0.52515
# 181/181 [==============================] - 47s 259ms/step - loss: 1.0864 - accuracy: 0.6155 - val_loss: 1.3496 - val_accuracy: 0.5233
# Epoch 18/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0702 - accuracy: 0.6213
# Epoch 18: val_accuracy did not improve from 0.52515
# 181/181 [==============================] - 47s 260ms/step - loss: 1.0702 - accuracy: 0.6213 - val_loss: 1.3584 - val_accuracy: 0.5175
# Epoch 19/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0559 - accuracy: 0.6257
# Epoch 19: val_accuracy improved from 0.52515 to 0.53480, saving model to model_weights.h5
# 181/181 [==============================] - 48s 264ms/step - loss: 1.0559 - accuracy: 0.6257 - val_loss: 1.3214 - val_accuracy: 0.5348
# Epoch 20/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0450 - accuracy: 0.6292
# Epoch 20: val_accuracy did not improve from 0.53480
# 181/181 [==============================] - 47s 259ms/step - loss: 1.0450 - accuracy: 0.6292 - val_loss: 1.3274 - val_accuracy: 0.5290
# Epoch 21/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0339 - accuracy: 0.6336
# Epoch 21: val_accuracy did not improve from 0.53480
# 181/181 [==============================] - 47s 259ms/step - loss: 1.0339 - accuracy: 0.6336 - val_loss: 1.3217 - val_accuracy: 0.5337
# Epoch 22/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0201 - accuracy: 0.6386
# Epoch 22: val_accuracy improved from 0.53480 to 0.53533, saving model to model_weights.h5
# 181/181 [==============================] - 49s 272ms/step - loss: 1.0201 - accuracy: 0.6386 - val_loss: 1.3112 - val_accuracy: 0.5353
# Epoch 23/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0118 - accuracy: 0.6411
# Epoch 23: val_accuracy did not improve from 0.53533
# 181/181 [==============================] - 47s 260ms/step - loss: 1.0118 - accuracy: 0.6411 - val_loss: 1.3485 - val_accuracy: 0.5336
# Epoch 24/100
# 181/181 [==============================] - ETA: 0s - loss: 1.0004 - accuracy: 0.6452
# Epoch 24: val_accuracy did not improve from 0.53533
# 181/181 [==============================] - 47s 259ms/step - loss: 1.0004 - accuracy: 0.6452 - val_loss: 1.3256 - val_accuracy: 0.5318
# Epoch 25/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9903 - accuracy: 0.6494
# Epoch 25: val_accuracy improved from 0.53533 to 0.54451, saving model to model_weights.h5
# 181/181 [==============================] - 47s 262ms/step - loss: 0.9903 - accuracy: 0.6494 - val_loss: 1.2947 - val_accuracy: 0.5445
# Epoch 26/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9825 - accuracy: 0.6529
# Epoch 26: val_accuracy did not improve from 0.54451
# 181/181 [==============================] - 47s 261ms/step - loss: 0.9825 - accuracy: 0.6529 - val_loss: 1.3474 - val_accuracy: 0.5312
# Epoch 27/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9700 - accuracy: 0.6553
# Epoch 27: val_accuracy improved from 0.54451 to 0.54469, saving model to model_weights.h5
# 181/181 [==============================] - 47s 260ms/step - loss: 0.9700 - accuracy: 0.6553 - val_loss: 1.2884 - val_accuracy: 0.5447
# Epoch 28/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9653 - accuracy: 0.6588
# Epoch 28: val_accuracy did not improve from 0.54469
# 181/181 [==============================] - 48s 265ms/step - loss: 0.9653 - accuracy: 0.6588 - val_loss: 1.2856 - val_accuracy: 0.5443
# Epoch 29/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9591 - accuracy: 0.6591
# Epoch 29: val_accuracy improved from 0.54469 to 0.54776, saving model to model_weights.h5
# 181/181 [==============================] - 48s 263ms/step - loss: 0.9591 - accuracy: 0.6591 - val_loss: 1.2941 - val_accuracy: 0.5478
# Epoch 30/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9468 - accuracy: 0.6644
# Epoch 30: val_accuracy did not improve from 0.54776
# 181/181 [==============================] - 47s 261ms/step - loss: 0.9468 - accuracy: 0.6644 - val_loss: 1.3184 - val_accuracy: 0.5362
# Epoch 31/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9434 - accuracy: 0.6653
# Epoch 31: val_accuracy did not improve from 0.54776
# 181/181 [==============================] - 47s 259ms/step - loss: 0.9434 - accuracy: 0.6653 - val_loss: 1.3172 - val_accuracy: 0.5412
# Epoch 32/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9359 - accuracy: 0.6671
# Epoch 32: val_accuracy improved from 0.54776 to 0.54853, saving model to model_weights.h5
# 181/181 [==============================] - 47s 261ms/step - loss: 0.9359 - accuracy: 0.6671 - val_loss: 1.2847 - val_accuracy: 0.5485
# Epoch 33/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9287 - accuracy: 0.6709
# Epoch 33: val_accuracy did not improve from 0.54853
# 181/181 [==============================] - 48s 263ms/step - loss: 0.9287 - accuracy: 0.6709 - val_loss: 1.3299 - val_accuracy: 0.5410
# Epoch 34/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9229 - accuracy: 0.6724
# Epoch 34: val_accuracy did not improve from 0.54853
# 181/181 [==============================] - 48s 262ms/step - loss: 0.9229 - accuracy: 0.6724 - val_loss: 1.3020 - val_accuracy: 0.5462
# Epoch 35/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9140 - accuracy: 0.6735
# Epoch 35: val_accuracy improved from 0.54853 to 0.55019, saving model to model_weights.h5
# 181/181 [==============================] - 48s 262ms/step - loss: 0.9140 - accuracy: 0.6735 - val_loss: 1.3039 - val_accuracy: 0.5502
# Epoch 36/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9063 - accuracy: 0.6783
# Epoch 36: val_accuracy did not improve from 0.55019
# 181/181 [==============================] - 47s 262ms/step - loss: 0.9063 - accuracy: 0.6783 - val_loss: 1.3114 - val_accuracy: 0.5472
# Epoch 37/100
# 181/181 [==============================] - ETA: 0s - loss: 0.9013 - accuracy: 0.6788
# Epoch 37: val_accuracy did not improve from 0.55019
# 181/181 [==============================] - 48s 263ms/step - loss: 0.9013 - accuracy: 0.6788 - val_loss: 1.2927 - val_accuracy: 0.5434
# Epoch 38/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8988 - accuracy: 0.6811
# Epoch 38: val_accuracy improved from 0.55019 to 0.55380, saving model to model_weights.h5
# 181/181 [==============================] - 47s 258ms/step - loss: 0.8988 - accuracy: 0.6811 - val_loss: 1.2899 - val_accuracy: 0.5538
# Epoch 39/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8932 - accuracy: 0.6822
# Epoch 39: val_accuracy improved from 0.55380 to 0.55463, saving model to model_weights.h5
# 181/181 [==============================] - 47s 260ms/step - loss: 0.8932 - accuracy: 0.6822 - val_loss: 1.2929 - val_accuracy: 0.5546
# Epoch 40/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8880 - accuracy: 0.6834
# Epoch 40: val_accuracy improved from 0.55463 to 0.56209, saving model to model_weights.h5
# 181/181 [==============================] - 48s 264ms/step - loss: 0.8880 - accuracy: 0.6834 - val_loss: 1.2721 - val_accuracy: 0.5621
# Epoch 41/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8823 - accuracy: 0.6862
# Epoch 41: val_accuracy did not improve from 0.56209
# 181/181 [==============================] - 48s 262ms/step - loss: 0.8823 - accuracy: 0.6862 - val_loss: 1.2866 - val_accuracy: 0.5594
# Epoch 42/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8763 - accuracy: 0.6873
# Epoch 42: val_accuracy did not improve from 0.56209
# 181/181 [==============================] - 47s 258ms/step - loss: 0.8763 - accuracy: 0.6873 - val_loss: 1.2508 - val_accuracy: 0.5605
# Epoch 43/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8716 - accuracy: 0.6892
# Epoch 43: val_accuracy did not improve from 0.56209
# 181/181 [==============================] - 48s 262ms/step - loss: 0.8716 - accuracy: 0.6892 - val_loss: 1.2897 - val_accuracy: 0.5589
# Epoch 44/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8678 - accuracy: 0.6903
# Epoch 44: val_accuracy did not improve from 0.56209
# 181/181 [==============================] - 49s 271ms/step - loss: 0.8678 - accuracy: 0.6903 - val_loss: 1.3018 - val_accuracy: 0.5535
# Epoch 45/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8594 - accuracy: 0.6945
# Epoch 45: val_accuracy did not improve from 0.56209
# 181/181 [==============================] - 48s 263ms/step - loss: 0.8594 - accuracy: 0.6945 - val_loss: 1.2749 - val_accuracy: 0.5562
# Epoch 46/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8554 - accuracy: 0.6958
# Epoch 46: val_accuracy did not improve from 0.56209
# 181/181 [==============================] - 47s 259ms/step - loss: 0.8554 - accuracy: 0.6958 - val_loss: 1.2754 - val_accuracy: 0.5592
# Epoch 47/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8527 - accuracy: 0.6947
# Epoch 47: val_accuracy did not improve from 0.56209
# 181/181 [==============================] - 47s 259ms/step - loss: 0.8527 - accuracy: 0.6947 - val_loss: 1.2872 - val_accuracy: 0.5584
# Epoch 48/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8451 - accuracy: 0.6972
# Epoch 48: val_accuracy improved from 0.56209 to 0.56564, saving model to model_weights.h5
# 181/181 [==============================] - 47s 261ms/step - loss: 0.8451 - accuracy: 0.6972 - val_loss: 1.2668 - val_accuracy: 0.5656
# Epoch 49/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8440 - accuracy: 0.6998
# Epoch 49: val_accuracy did not improve from 0.56564
# 181/181 [==============================] - 48s 266ms/step - loss: 0.8440 - accuracy: 0.6998 - val_loss: 1.2976 - val_accuracy: 0.5514
# Epoch 50/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8367 - accuracy: 0.7028
# Epoch 50: val_accuracy improved from 0.56564 to 0.56960, saving model to model_weights.h5
# 181/181 [==============================] - 48s 262ms/step - loss: 0.8367 - accuracy: 0.7028 - val_loss: 1.2469 - val_accuracy: 0.5696
# Epoch 51/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8306 - accuracy: 0.7032
# Epoch 51: val_accuracy did not improve from 0.56960
# 181/181 [==============================] - 47s 258ms/step - loss: 0.8306 - accuracy: 0.7032 - val_loss: 1.2742 - val_accuracy: 0.5624
# Epoch 52/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8277 - accuracy: 0.7047
# Epoch 52: val_accuracy did not improve from 0.56960
# 181/181 [==============================] - 47s 260ms/step - loss: 0.8277 - accuracy: 0.7047 - val_loss: 1.3354 - val_accuracy: 0.5413
# Epoch 53/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8236 - accuracy: 0.7062
# Epoch 53: val_accuracy did not improve from 0.56960
# 181/181 [==============================] - 47s 261ms/step - loss: 0.8236 - accuracy: 0.7062 - val_loss: 1.2495 - val_accuracy: 0.5684
# Epoch 54/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8193 - accuracy: 0.7076
# Epoch 54: val_accuracy improved from 0.56960 to 0.56990, saving model to model_weights.h5
# 181/181 [==============================] - 47s 260ms/step - loss: 0.8193 - accuracy: 0.7076 - val_loss: 1.2319 - val_accuracy: 0.5699
# Epoch 55/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8131 - accuracy: 0.7100
# Epoch 55: val_accuracy improved from 0.56990 to 0.57150, saving model to model_weights.h5
# 181/181 [==============================] - 47s 260ms/step - loss: 0.8131 - accuracy: 0.7100 - val_loss: 1.2394 - val_accuracy: 0.5715
# Epoch 56/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8096 - accuracy: 0.7100
# Epoch 56: val_accuracy did not improve from 0.57150
# 181/181 [==============================] - 47s 261ms/step - loss: 0.8096 - accuracy: 0.7100 - val_loss: 1.2682 - val_accuracy: 0.5606
# Epoch 57/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8063 - accuracy: 0.7089
# Epoch 57: val_accuracy did not improve from 0.57150
# 181/181 [==============================] - 48s 265ms/step - loss: 0.8063 - accuracy: 0.7089 - val_loss: 1.2842 - val_accuracy: 0.5601
# Epoch 58/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7994 - accuracy: 0.7143
# Epoch 58: val_accuracy did not improve from 0.57150
# 181/181 [==============================] - 48s 262ms/step - loss: 0.7994 - accuracy: 0.7143 - val_loss: 1.2508 - val_accuracy: 0.5661
# Epoch 59/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7968 - accuracy: 0.7145
# Epoch 59: val_accuracy did not improve from 0.57150
# 181/181 [==============================] - 49s 271ms/step - loss: 0.7968 - accuracy: 0.7145 - val_loss: 1.2811 - val_accuracy: 0.5632
# Epoch 60/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7922 - accuracy: 0.7170
# Epoch 60: val_accuracy did not improve from 0.57150
# 181/181 [==============================] - 48s 263ms/step - loss: 0.7922 - accuracy: 0.7170 - val_loss: 1.2649 - val_accuracy: 0.5669
# Epoch 61/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7901 - accuracy: 0.7174
# Epoch 61: val_accuracy did not improve from 0.57150
# 181/181 [==============================] - 48s 262ms/step - loss: 0.7901 - accuracy: 0.7174 - val_loss: 1.2770 - val_accuracy: 0.5659
# Epoch 62/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7856 - accuracy: 0.7183
# Epoch 62: val_accuracy did not improve from 0.57150
# 181/181 [==============================] - 49s 270ms/step - loss: 0.7856 - accuracy: 0.7183 - val_loss: 1.2708 - val_accuracy: 0.5694
# Epoch 63/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7776 - accuracy: 0.7228
# Epoch 63: val_accuracy did not improve from 0.57150
# 181/181 [==============================] - 48s 263ms/step - loss: 0.7776 - accuracy: 0.7228 - val_loss: 1.2819 - val_accuracy: 0.5668
# Epoch 64/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7784 - accuracy: 0.7216
# Epoch 64: val_accuracy did not improve from 0.57150
# 181/181 [==============================] - 48s 264ms/step - loss: 0.7784 - accuracy: 0.7216 - val_loss: 1.3138 - val_accuracy: 0.5592
# Epoch 65/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7720 - accuracy: 0.7225
# Epoch 65: val_accuracy improved from 0.57150 to 0.57197, saving model to model_weights.h5
# 181/181 [==============================] - 48s 263ms/step - loss: 0.7720 - accuracy: 0.7225 - val_loss: 1.2753 - val_accuracy: 0.5720
# Epoch 66/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7667 - accuracy: 0.7246
# Epoch 66: val_accuracy did not improve from 0.57197
# 181/181 [==============================] - 47s 258ms/step - loss: 0.7667 - accuracy: 0.7246 - val_loss: 1.3093 - val_accuracy: 0.5634
# Epoch 67/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.7276
# Epoch 67: val_accuracy did not improve from 0.57197
# 181/181 [==============================] - 47s 260ms/step - loss: 0.7637 - accuracy: 0.7276 - val_loss: 1.3237 - val_accuracy: 0.5585
# Epoch 68/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7585 - accuracy: 0.7288
# Epoch 68: val_accuracy did not improve from 0.57197
# 181/181 [==============================] - 48s 262ms/step - loss: 0.7585 - accuracy: 0.7288 - val_loss: 1.2681 - val_accuracy: 0.5695
# Epoch 69/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7568 - accuracy: 0.7286
# Epoch 69: val_accuracy did not improve from 0.57197
# 181/181 [==============================] - 50s 273ms/step - loss: 0.7568 - accuracy: 0.7286 - val_loss: 1.3147 - val_accuracy: 0.5602
# Epoch 70/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7556 - accuracy: 0.7289
# Epoch 70: val_accuracy improved from 0.57197 to 0.57209, saving model to model_weights.h5
# 181/181 [==============================] - 50s 273ms/step - loss: 0.7556 - accuracy: 0.7289 - val_loss: 1.2734 - val_accuracy: 0.5721
# Epoch 71/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7471 - accuracy: 0.7316
# Epoch 71: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 47s 261ms/step - loss: 0.7471 - accuracy: 0.7316 - val_loss: 1.3267 - val_accuracy: 0.5604
# Epoch 72/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7477 - accuracy: 0.7324
# Epoch 72: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 262ms/step - loss: 0.7477 - accuracy: 0.7324 - val_loss: 1.2871 - val_accuracy: 0.5682
# Epoch 73/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7428 - accuracy: 0.7325
# Epoch 73: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 264ms/step - loss: 0.7428 - accuracy: 0.7325 - val_loss: 1.2950 - val_accuracy: 0.5639
# Epoch 74/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7390 - accuracy: 0.7343
# Epoch 74: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 49s 268ms/step - loss: 0.7390 - accuracy: 0.7343 - val_loss: 1.3233 - val_accuracy: 0.5645
# Epoch 75/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7344 - accuracy: 0.7367
# Epoch 75: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 262ms/step - loss: 0.7344 - accuracy: 0.7367 - val_loss: 1.2985 - val_accuracy: 0.5613
# Epoch 76/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7290 - accuracy: 0.7367
# Epoch 76: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 263ms/step - loss: 0.7290 - accuracy: 0.7367 - val_loss: 1.3255 - val_accuracy: 0.5644
# Epoch 77/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7281 - accuracy: 0.7395
# Epoch 77: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 49s 268ms/step - loss: 0.7281 - accuracy: 0.7395 - val_loss: 1.2783 - val_accuracy: 0.5706
# Epoch 78/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7240 - accuracy: 0.7388
# Epoch 78: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 49s 270ms/step - loss: 0.7240 - accuracy: 0.7388 - val_loss: 1.2944 - val_accuracy: 0.5694
# Epoch 79/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7221 - accuracy: 0.7397
# Epoch 79: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 262ms/step - loss: 0.7221 - accuracy: 0.7397 - val_loss: 1.3239 - val_accuracy: 0.5602
# Epoch 80/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7167 - accuracy: 0.7419
# Epoch 80: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 47s 261ms/step - loss: 0.7167 - accuracy: 0.7419 - val_loss: 1.3149 - val_accuracy: 0.5654
# Epoch 81/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7126 - accuracy: 0.7437
# Epoch 81: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 47s 260ms/step - loss: 0.7126 - accuracy: 0.7437 - val_loss: 1.3140 - val_accuracy: 0.5643
# Epoch 82/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7116 - accuracy: 0.7443
# Epoch 82: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 47s 259ms/step - loss: 0.7116 - accuracy: 0.7443 - val_loss: 1.3208 - val_accuracy: 0.5610
# Epoch 83/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7037 - accuracy: 0.7477
# Epoch 83: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 265ms/step - loss: 0.7037 - accuracy: 0.7477 - val_loss: 1.3139 - val_accuracy: 0.5683
# Epoch 84/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6987 - accuracy: 0.7486
# Epoch 84: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 263ms/step - loss: 0.6987 - accuracy: 0.7486 - val_loss: 1.3290 - val_accuracy: 0.5616
# Epoch 85/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6983 - accuracy: 0.7489
# Epoch 85: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 263ms/step - loss: 0.6983 - accuracy: 0.7489 - val_loss: 1.3493 - val_accuracy: 0.5600
# Epoch 86/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.7498
# Epoch 86: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 49s 272ms/step - loss: 0.6940 - accuracy: 0.7498 - val_loss: 1.3042 - val_accuracy: 0.5689
# Epoch 87/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.7496
# Epoch 87: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 47s 258ms/step - loss: 0.6935 - accuracy: 0.7496 - val_loss: 1.3490 - val_accuracy: 0.5623
# Epoch 88/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6913 - accuracy: 0.7499
# Epoch 88: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 262ms/step - loss: 0.6913 - accuracy: 0.7499 - val_loss: 1.2955 - val_accuracy: 0.5690
# Epoch 89/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6867 - accuracy: 0.7514
# Epoch 89: val_accuracy did not improve from 0.57209
# 181/181 [==============================] - 48s 265ms/step - loss: 0.6867 - accuracy: 0.7514 - val_loss: 1.3223 - val_accuracy: 0.5663
# Epoch 90/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6849 - accuracy: 0.7506
# Epoch 90: val_accuracy improved from 0.57209 to 0.57232, saving model to model_weights.h5
# 181/181 [==============================] - 48s 262ms/step - loss: 0.6849 - accuracy: 0.7506 - val_loss: 1.3105 - val_accuracy: 0.5723
# Epoch 91/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6796 - accuracy: 0.7538
# Epoch 91: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 48s 262ms/step - loss: 0.6796 - accuracy: 0.7538 - val_loss: 1.3481 - val_accuracy: 0.5600
# Epoch 92/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6757 - accuracy: 0.7555
# Epoch 92: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 47s 261ms/step - loss: 0.6757 - accuracy: 0.7555 - val_loss: 1.3274 - val_accuracy: 0.5697
# Epoch 93/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6715 - accuracy: 0.7576
# Epoch 93: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 47s 260ms/step - loss: 0.6715 - accuracy: 0.7576 - val_loss: 1.3314 - val_accuracy: 0.5722
# Epoch 94/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6666 - accuracy: 0.7586
# Epoch 94: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 48s 262ms/step - loss: 0.6666 - accuracy: 0.7586 - val_loss: 1.3181 - val_accuracy: 0.5671
# Epoch 95/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6641 - accuracy: 0.7594
# Epoch 95: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 47s 262ms/step - loss: 0.6641 - accuracy: 0.7594 - val_loss: 1.3352 - val_accuracy: 0.5603
# Epoch 96/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6623 - accuracy: 0.7596
# Epoch 96: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 48s 264ms/step - loss: 0.6623 - accuracy: 0.7596 - val_loss: 1.3289 - val_accuracy: 0.5633
# Epoch 97/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.7611
# Epoch 97: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 47s 260ms/step - loss: 0.6596 - accuracy: 0.7611 - val_loss: 1.3545 - val_accuracy: 0.5631
# Epoch 98/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6573 - accuracy: 0.7617
# Epoch 98: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 49s 270ms/step - loss: 0.6573 - accuracy: 0.7617 - val_loss: 1.3396 - val_accuracy: 0.5691
# Epoch 99/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6521 - accuracy: 0.7649
# Epoch 99: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 48s 264ms/step - loss: 0.6521 - accuracy: 0.7649 - val_loss: 1.3530 - val_accuracy: 0.5610
# Epoch 100/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6478 - accuracy: 0.7651
# Epoch 100: val_accuracy did not improve from 0.57232
# 181/181 [==============================] - 49s 272ms/step - loss: 0.6478 - accuracy: 0.7651 - val_loss: 1.3583 - val_accuracy: 0.5631

# %%
# NOT CHANGED! # DO NOT USE LIKE THIS
model.save_weights("./model.h5")

# %%
# NOT CHANGED # DO NOT USE LIKE THIS!
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
