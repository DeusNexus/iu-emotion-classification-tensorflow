# %%
import os
import json

def find_highest_metric(folder_path, metric):
    max_metric_value = 0.0
    best_file = None

    for filename in os.listdir(folder_path):
        if filename.endswith(".json"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                data = json.load(file)
                metric_values = data[metric]
                max_metric_value_file = max(metric_values)
                if max_metric_value_file > max_metric_value:
                    max_metric_value = max_metric_value_file
                    best_file = file_path

    return best_file, max_metric_value

def rank_val_accuracy(folder_path):
    val_accuracy_ranking = []

    for filename in os.listdir(folder_path):
        if filename.endswith(".json"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                data = json.load(file)
                val_accuracy = max(data["val_accuracy"])
                val_accuracy_ranking.append((file_path, val_accuracy))

    # Sort the ranking in descending order based on val_accuracy
    val_accuracy_ranking.sort(key=lambda x: x[1], reverse=True)

    return val_accuracy_ranking

metrics_to_check = ["accuracy", "loss", "val_accuracy", "val_loss"]

# Replace 'models/training/history' with the actual path to your folder containing JSON files
folder_path = '../models/training/history'

for metric in metrics_to_check:
    best_file, max_metric_value = find_highest_metric(folder_path, metric)
    if best_file is not None:
        print(f"The file with the highest {metric} is: {best_file}")
        print(f"The highest {metric} is: {max_metric_value}")
    else:
        print(f"No JSON files found in the specified folder for {metric}.")
    print("\n")

val_accuracy_ranking = rank_val_accuracy(folder_path)

if val_accuracy_ranking:
    print("Ranking of files based on val_accuracy:")
    for rank, (file_path, val_accuracy) in enumerate(val_accuracy_ranking, 1):
        print(f"{rank}. File: {file_path}, val_accuracy: {val_accuracy}")
else:
    print("No JSON files found in the specified folder.")
# Out:
# The file with the highest accuracy is: ../models/training/history/model_3_best_nodropout_adam_rgb_512_augment_history.json
# The highest accuracy is: 0.9606190919876099
#
#
# The file with the highest loss is: ../models/training/history/model_2_best_rmsprop_rgb_512_augment_history.json
# The highest loss is: 1.7501258850097656
#
#
# The file with the highest val_accuracy is: ../models/training/history/model_2_best_sgd_rgb_128_augment_history.json
# The highest val_accuracy is: 0.5928241014480591
#
#
# The file with the highest val_loss is: ../models/training/history/model_3_best_nodropout_sgd_rgb_32_augment_history.json
# The highest val_loss is: 2497.628173828125
#
#
# Ranking of files based on val_accuracy:
# 1. File: ../models/training/history/model_2_best_sgd_rgb_128_augment_history.json, val_accuracy: 0.5928241014480591
# 2. File: ../models/training/history/model_2_best_rmsprop_rgb_256_augment_history.json, val_accuracy: 0.59275883436203
# 3. File: ../models/training/history/model_2_best_rmsprop_rgb_128_augment_history.json, val_accuracy: 0.5925925970077515
# 4. File: ../models/training/history/model_2_best_adam_rgb_128_augment_history.json, val_accuracy: 0.5919560194015503
# 5. File: ../models/training/history/model_2_best_rmsprop_rgb_512_augment_history.json, val_accuracy: 0.5916785001754761
# 6. File: ../models/training/history/model_2_best_sgd_rgb_64_augment_history.json, val_accuracy: 0.5905212163925171
# 7. File: ../models/training/history/model_2_best_adam_rgb_256_augment_history.json, val_accuracy: 0.5899020433425903
# 8. File: ../models/training/history/model_2_best_sgd_rgb_256_augment_history.json, val_accuracy: 0.5892607569694519
# 9. File: ../models/training/history/model_2_best_adam_rgb_32_augment_history.json, val_accuracy: 0.5889644622802734
# 10. File: ../models/training/history/model_2_best_sgd_rgb_32_augment_history.json, val_accuracy: 0.5880996584892273
# 11. File: ../models/training/history/model_2_best_sgd_rgb_512_augment_history.json, val_accuracy: 0.5870620012283325
# 12. File: ../models/training/history/model_2_best_adam_rgb_64_augment_history.json, val_accuracy: 0.5864275693893433
# 13. File: ../models/training/history/model_2_best_rmsprop_grayscale_64_augment_history.json, val_accuracy: 0.5861393213272095
# 14. File: ../models/training/history/model_1_concept_adam_rgb_128_augment_history.json, val_accuracy: 0.5858796238899231
# 15. File: ../models/training/history/model_2_best_rmsprop_rgb_32_augment_history.json, val_accuracy: 0.5857356786727905
# 16. File: ../models/training/history/model_2_best_adam_grayscale_64_augment_history.json, val_accuracy: 0.5840060114860535
# 17. File: ../models/training/history/model_2_best_adam_rgb_512_augment_history.json, val_accuracy: 0.5836292505264282
# 18. File: ../models/training/history/model_2_best_rmsprop_grayscale_128_augment_history.json, val_accuracy: 0.5834490656852722
# 19. File: ../models/training/history/model_2_best_adam_grayscale_128_augment_history.json, val_accuracy: 0.5826967358589172
# 20. File: ../models/training/history/model_2_best_sgd_grayscale_64_augment_history.json, val_accuracy: 0.5814691185951233
# 21. File: ../models/training/history/model_1_concept_rmsprop_rgb_512_augment_history.json, val_accuracy: 0.5812618136405945
# 22. File: ../models/training/history/model_2_best_sgd_grayscale_32_augment_history.json, val_accuracy: 0.5812384486198425
# 23. File: ../models/training/history/model_2_best_rmsprop_rgb_64_augment_history.json, val_accuracy: 0.580488920211792
# 24. File: ../models/training/history/model_2_best_sgd_grayscale_128_augment_history.json, val_accuracy: 0.5802661776542664
# 25. File: ../models/training/history/model_3_best_nodropout_adam_rgb_32_augment_history.json, val_accuracy: 0.58002769947052
# 26. File: ../models/training/history/model_3_best_nodropout_adam_grayscale_128_augment_history.json, val_accuracy: 0.5784143805503845
# 27. File: ../models/training/history/model_2_best_rmsprop_grayscale_32_augment_history.json, val_accuracy: 0.5774331092834473
# 28. File: ../models/training/history/model_3_best_nodropout_sgd_rgb_64_augment_history.json, val_accuracy: 0.5767989158630371
# 29. File: ../models/training/history/model_1_concept_sgd_rgb_64_augment_history.json, val_accuracy: 0.57622230052948
# 30. File: ../models/training/history/model_2_best_adam_grayscale_32_augment_history.json, val_accuracy: 0.5759340524673462
# 31. File: ../models/training/history/model_4_best_nodroupout_nobatchn_sgd_rgb_512_augment_history.json, val_accuracy: 0.5746922492980957
# 32. File: ../models/training/history/model_1_concept_adam_rgb_32_augment_history.json, val_accuracy: 0.5741466879844666
# 33. File: ../models/training/history/model_3_best_nodropout_adam_rgb_64_augment_history.json, val_accuracy: 0.5736854076385498
# 34. File: ../models/training/history/model_3_best_nodropout_rmsprop_rgb_128_augment_history.json, val_accuracy: 0.5725694298744202
# 35. File: ../models/training/history/model_1_concept_rmsprop_rgb_256_augment_history.json, val_accuracy: 0.5718283653259277
# 36. File: ../models/training/history/model_1_concept_sgd_rgb_256_augment_history.json, val_accuracy: 0.5717700719833374
# 37. File: ../models/training/history/model_1_concept_adam_rgb_64_augment_history.json, val_accuracy: 0.5716097950935364
# 38. File: ../models/training/history/model_1_concept_adam_rgb_256_augment_history.json, val_accuracy: 0.5713619589805603
# 39. File: ../models/training/history/model_3_best_nodropout_sgd_rgb_256_augment_history.json, val_accuracy: 0.5713619589805603
# 40. File: ../models/training/history/model_3_best_nodropout_adam_rgb_256_augment_history.json, val_accuracy: 0.5712453126907349
# 41. File: ../models/training/history/model_3_best_nodropout_rmsprop_rgb_32_augment_history.json, val_accuracy: 0.5711485147476196
# 42. File: ../models/training/history/model_1_concept_rmsprop_rgb_64_augment_history.json, val_accuracy: 0.5710908770561218
# 43. File: ../models/training/history/model_3_best_nodropout_adam_rgb_128_augment_history.json, val_accuracy: 0.5709490776062012
# 44. File: ../models/training/history/model_3_best_nodropout_sgd_grayscale_32_augment_history.json, val_accuracy: 0.5705143213272095
# 45. File: ../models/training/history/model_1_concept_sgd_rgb_512_augment_history.json, val_accuracy: 0.570253312587738
# 46. File: ../models/training/history/model_1_concept_sgd_rgb_128_augment_history.json, val_accuracy: 0.5686342716217041
# 47. File: ../models/training/history/model_4_best_nodroupout_nobatchn_rmsprop_rgb_256_augment_history.json, val_accuracy: 0.5685051083564758
# 48. File: ../models/training/history/model_1_concept_sgd_grayscale_64_augment_history.json, val_accuracy: 0.5678044557571411
# 49. File: ../models/training/history/model_3_best_nodropout_rmsprop_rgb_64_augment_history.json, val_accuracy: 0.5668818950653076
# 50. File: ../models/training/history/model_3_best_nodropout_rmsprop_grayscale_64_augment_history.json, val_accuracy: 0.5665936470031738
# 51. File: ../models/training/history/model_1_concept_rmsprop_rgb_128_augment_history.json, val_accuracy: 0.5664351582527161
# 52. File: ../models/training/history/model_3_best_nodropout_sgd_rgb_32_augment_history.json, val_accuracy: 0.5660747289657593
# 53. File: ../models/training/history/model_1_concept_adam_rgb_512_augment_history.json, val_accuracy: 0.5659919381141663
# 54. File: ../models/training/history/model_4_best_nodroupout_nobatchn_rmsprop_rgb_512_augment_history.json, val_accuracy: 0.5658735632896423
# 55. File: ../models/training/history/model_1_concept_sgd_grayscale_32_augment_history.json, val_accuracy: 0.5647486448287964
# 56. File: ../models/training/history/model_3_best_nodropout_adam_grayscale_64_augment_history.json, val_accuracy: 0.564633309841156
# 57. File: ../models/training/history/model_1_concept_rmsprop_grayscale_128_augment_history.json, val_accuracy: 0.5641782283782959
# 58. File: ../models/training/history/model_3_best_nodropout_rmsprop_rgb_256_augment_history.json, val_accuracy: 0.5633745193481445
# 59. File: ../models/training/history/model_3_best_nodropout_sgd_grayscale_64_augment_history.json, val_accuracy: 0.562730610370636
# 60. File: ../models/training/history/model_3_best_nodropout_sgd_rgb_512_augment_history.json, val_accuracy: 0.5626183748245239
# 61. File: ../models/training/history/model_3_best_nodropout_rmsprop_grayscale_128_augment_history.json, val_accuracy: 0.5623263716697693
# 62. File: ../models/training/history/model_1_concept_sgd_rgb_32_augment_history.json, val_accuracy: 0.5621540546417236
# 63. File: ../models/training/history/model_3_best_nodropout_sgd_grayscale_128_augment_history.json, val_accuracy: 0.5620370507240295
# 64. File: ../models/training/history/model_1_concept_rmsprop_rgb_32_augment_history.json, val_accuracy: 0.5617504715919495
# 65. File: ../models/training/history/model_3_best_nodropout_rmsprop_grayscale_32_augment_history.json, val_accuracy: 0.5614621639251709
# 66. File: ../models/training/history/model_4_best_nodroupout_nobatchn_adam_rgb_256_augment_history.json, val_accuracy: 0.561159074306488
# 67. File: ../models/training/history/model_1_concept_adam_grayscale_32_augment_history.json, val_accuracy: 0.5608856081962585
# 68. File: ../models/training/history/model_3_best_nodropout_sgd_rgb_128_augment_history.json, val_accuracy: 0.560879647731781
# 69. File: ../models/training/history/model_1_concept_adam_grayscale_64_augment_history.json, val_accuracy: 0.5607702732086182
# 70. File: ../models/training/history/model_4_best_nodroupout_nobatchn_adam_rgb_512_augment_history.json, val_accuracy: 0.5588304996490479
# 71. File: ../models/training/history/model_4_best_nodroupout_nobatchn_rmsprop_rgb_64_augment_history.json, val_accuracy: 0.5585793256759644
# 72. File: ../models/training/history/model_4_best_nodroupout_nobatchn_rmsprop_rgb_128_augment_history.json, val_accuracy: 0.5579282641410828
# 73. File: ../models/training/history/model_3_best_nodropout_adam_grayscale_32_augment_history.json, val_accuracy: 0.5575991868972778
# 74. File: ../models/training/history/model_4_best_nodroupout_nobatchn_adam_grayscale_128_augment_history.json, val_accuracy: 0.5575810074806213
# 75. File: ../models/training/history/model_1_concept_rmsprop_grayscale_64_augment_history.json, val_accuracy: 0.5565613508224487
# 76. File: ../models/training/history/model_1_concept_rmsprop_grayscale_32_augment_history.json, val_accuracy: 0.5561577677726746
# 77. File: ../models/training/history/model_1_concept_sgd_grayscale_128_augment_history.json, val_accuracy: 0.555439829826355
# 78. File: ../models/training/history/model_4_best_nodroupout_nobatchn_adam_rgb_128_augment_history.json, val_accuracy: 0.553935170173645
# 79. File: ../models/training/history/model_3_best_nodropout_adam_rgb_512_augment_history.json, val_accuracy: 0.5536813735961914
# 80. File: ../models/training/history/model_1_concept_adam_grayscale_128_augment_history.json, val_accuracy: 0.5532407164573669
# 81. File: ../models/training/history/model_4_best_nodroupout_nobatchn_sgd_rgb_128_augment_history.json, val_accuracy: 0.5525463223457336
# 82. File: ../models/training/history/model_4_best_nodroupout_nobatchn_sgd_rgb_256_augment_history.json, val_accuracy: 0.5522388219833374
# 83. File: ../models/training/history/model_4_best_nodroupout_nobatchn_rmsprop_grayscale_128_augment_history.json, val_accuracy: 0.5517939925193787
# 84. File: ../models/training/history/model_4_best_nodroupout_nobatchn_sgd_grayscale_128_augment_history.json, val_accuracy: 0.5511574149131775
# 85. File: ../models/training/history/model_4_best_nodroupout_nobatchn_rmsprop_grayscale_64_augment_history.json, val_accuracy: 0.5450876355171204
# 86. File: ../models/training/history/model_4_best_nodroupout_nobatchn_adam_rgb_64_augment_history.json, val_accuracy: 0.5446840524673462
# 87. File: ../models/training/history/model_4_best_nodroupout_nobatchn_sgd_grayscale_64_augment_history.json, val_accuracy: 0.5440497994422913
# 88. File: ../models/training/history/model_4_best_nodroupout_nobatchn_sgd_rgb_64_augment_history.json, val_accuracy: 0.5437615513801575
# 89. File: ../models/training/history/model_3_best_nodropout_rmsprop_rgb_512_augment_history.json, val_accuracy: 0.5433238744735718
# 90. File: ../models/training/history/model_4_best_nodroupout_nobatchn_sgd_rgb_32_augment_history.json, val_accuracy: 0.5430119633674622
# 91. File: ../models/training/history/model_4_best_nodroupout_nobatchn_adam_rgb_32_augment_history.json, val_accuracy: 0.5416282415390015
# 92. File: ../models/training/history/model_4_best_nodroupout_nobatchn_adam_grayscale_32_augment_history.json, val_accuracy: 0.5389183759689331
# 93. File: ../models/training/history/model_4_best_nodroupout_nobatchn_rmsprop_rgb_32_augment_history.json, val_accuracy: 0.5364391207695007
# 94. File: ../models/training/history/model_4_best_nodroupout_nobatchn_adam_grayscale_64_augment_history.json, val_accuracy: 0.5343058109283447
# 95. File: ../models/training/history/model_4_best_nodroupout_nobatchn_rmsprop_grayscale_32_augment_history.json, val_accuracy: 0.5249077677726746
# 96. File: ../models/training/history/model_4_best_nodroupout_nobatchn_sgd_grayscale_32_augment_history.json, val_accuracy: 0.33660054206848145
